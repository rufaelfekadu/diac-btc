# %%
import re
import json
import unicodedata
import pandas as pd
from pathlib import Path
from collections import Counter

import sys

sys.path.append("../")
from text_processing_utils import (
    preprocess_text,
    tokenize_text,
    form_wildcard_pattern,
    get_groups_of_characters_with_diacritics,
)

pd.set_option("display.max_colwidth", None)

# %%
form_wildcard_pattern("123 - فَمِنَ الرَّامِي السُّوِيدِيِّ أُوسْكَار")
# Out:
# ['1',
#  '2',
#  '3',
#  ' ',
#  '-',
#  ' ',
#  'ف',
#  '<*>',
#  'م',
#  '<*>',
#  'ن',
#  '<*>',
#  ' ',
#  'ا',
#  '<*>',
#  'ل',
#  '<*>',
#  'ر',
#  '<*>',
#  'ا',
#  '<*>',
#  'م',
#  '<*>',
#  'ي',
#  '<*>',
#  ' ',
#  'ا',
#  '<*>',
#  'ل',
#  '<*>',
#  'س',
#  '<*>',
#  'و',
#  '<*>',
#  'ي',
#  '<*>',
#  'د',
#  '<*>',
#  'ي',
#  '<*>',
#  ' ',
#  'أ',
#  '<*>',
#  'و',
#  '<*>',
#  'س',
#  '<*>',
#  'ك',
#  '<*>',
#  'ا',
#  '<*>',
#  'ر',
#  '<*>']

# %%
# Ad-hoc fix of the json files' format
def load_file_lines(filename):
    with open(filename, "r") as f:
        lines = "\n".join([l.strip() for l in f if l.strip()])
        lines = re.sub(r"}\n{", r"},\n{", lines)
        lines = "[\n" + lines + "\n]"
    return json.loads(lines)


DATA_DIR = Path("../data/")
filenames = sorted([f for f in DATA_DIR.glob("*_metadata*")])

# %%
def generate_information_report(filename):
    data = load_file_lines(filename)
    df = pd.DataFrame(data)
    df.rename(columns={"transcript": "text", "transcription": "text"}, inplace=True)

    df["preprocessed_text"] = df["text"].apply(lambda t: preprocess_text(t))

    # Find the diacritics that follow each character
    df["characters_diacritics"] = df["preprocessed_text"].apply(
        get_groups_of_characters_with_diacritics
    )

    char_counts = Counter([c for t in df["preprocessed_text"] for c in t]).most_common()

    info_df = pd.DataFrame(
        [{"Character": ch, "Count": count} for ch, count in char_counts]
    )
    info_df["Code"] = info_df["Character"].apply(lambda ch: ord(ch))
    info_df["Name"] = info_df["Character"].apply(lambda ch: unicodedata.name(ch))

    # Mn -> diacritic
    info_df["Type"] = info_df["Character"].apply(lambda ch: unicodedata.category(ch))
    info_df["is_diacritic"] = info_df["Type"].apply(lambda t: t == "Mn")

    # Build the set of diacritics following each character
    character_to_following_diacritics = {}
    for i, l in enumerate(df["characters_diacritics"].tolist()):
        for ch, dia_list in l:
            if ch not in character_to_following_diacritics:
                character_to_following_diacritics[ch] = []
            character_to_following_diacritics[ch].append(
                ("+".join([unicodedata.name(d) for d in dia_list]), dia_list)
            )

    info_df["Following_diacritics"] = info_df["Character"].apply(
        lambda c: Counter(character_to_following_diacritics.get(c, None)).most_common()
    )

    info_df.sort_values(
        by=["is_diacritic", "Code", "Count"], ascending=True, inplace=True
    )

    return info_df

# %% [markdown]
# ## ArVoice dataset

# %% [markdown]
# ### Summary:
# - Vowels such as أاإ sometimes have diacritics following themة
#     - e.g., `أُعْلِنَ يَوْمَ ...`
#     - <span style="color:red">Question: Are we going to add wildcard tokens after these characters, based on this finding?</span>
# - **Note:** I decided not to resolve any of the potential errors reported below in the preprocessing script, as they are all rare.
# ##### Annotation errors (ArVoice - test set):
# - Rare occurences of an incomplete diacritics combination:
#     - 11 times `ARABIC SHADDA` is on its own, without an accompanying short vowel
#     - **Note:** This is going to be mapped to `<UNK_DIAC>` in the main experiment
# - Two cases of a diacritic following the `SPACE` character
#     - <span style="color:red">Question: How is this handled when computing the different error rates?</span>
#
# ##### Annotation errors (ArVoice - train set):
# - Rare occurences of Invalid diacritics combinations:
#     - 4 times `ARABIC KASRA+ARABIC KASRA`, once `ARABIC KASRA+ARABIC SUKUN`, once `ARABIC FATHA+ARABIC KASRA`
#     - **Note:** This is going to be mapped to `<UNK_DIAC>` in the main experiment
# - The `TATWEEL` character only exists in this dataset
#     - Out of 26 times, it was (mistakenly?) diacritized once

# %%
df = pd.DataFrame(load_file_lines(filenames[0]))
df[df["transcription"].apply(lambda t: "أُ" in t)]
# Out:
#                                                              file_name  \
# 5    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00018.wav
# 6    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00022.wav
# 7    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00010.wav
# 8    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00023.wav
# 10   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00039.wav
# 21   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00015.wav
# 28   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ab_00025.wav
# 41   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00060.wav
# 43   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00062.wav
# 48   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00061.wav
# 50   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00069.wav
# 52   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00072.wav
# 53   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00051.wav
# 69   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00073.wav
# 71   /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/female_ad_00070.wav
# 76     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00092.wav
# 80     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00100.wav
# 84     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00080.wav
# 88     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00115.wav
# 94     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00093.wav
# 97     /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00086.wav
# 101    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00103.wav
# 106    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_aa_00111.wav
# 113    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00131.wav
# 114    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00124.wav
# 120    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00152.wav
# 121    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00119.wav
# 122    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00138.wav
# 123    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00118.wav
# 130    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00144.wav
# 135    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00134.wav
# 141    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00133.wav
# 142    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00122.wav
# 146    /l/ArVoice/v1/part-1/tashkeela/tashkeela-test/male_ac_00117.wav
# 160               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0002.wav
# 180               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0022.wav
# 181               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0023.wav
# 184               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0026.wav
# 193               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0035.wav
# 196               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0038.wav
# 203               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0045.wav
# 206               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0048.wav
# 211               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0053.wav
# 212               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0054.wav
# 216               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0058.wav
# 217               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0059.wav
# 220               /l/ArVoice/v1/part-2/asc/asc-test/ARA_NORM__0062.wav
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcription  \
# 5                                                                                     صَعَدَتْ أَسْعَارُ النَّفْطِ الْجُمْعَةَ مُوَسِّعَةً مَكَاسِبَهَا إلَى أَكْثَرَ مِنْ خَمْسَةٍ وَ عِشْرينْ مُنْذُ أَنْ هَوَتِ الْأُسْبُوعَ الْمَاضِيَ إلَى أَدْنَى مُسْتَوَيَاتِهَا فِي إِثْنا عَشَرَ عَامًا وَذَلِكَ بِدَعْمٍ مِنْ تَوَقُّعَاتٍ بِاتِّفَاقٍ بَيْنَ مُصَدِّرِي النَّفْطِ الرَّئِيسِيِّينَ لِخَفْضِ الْإِنْتَاجِ وَكَبْحِ وَاحِدَةٍ مِنْ أَكْبَرِ تُخَمِ الْإِمْدَادَاتِ فِي التَّارِيخِ
# 6                                                                                                  يُعْرَضُ الْقِيثارُ الْكَهْرَبَائِيُّ الَّذِي عَزَفَ عَلَيْهِ جُونْ لِينُون عِنْدَمَا كَانَ عُضْوًا فِي فِرْقَةِ الْبِيتِلْز أُغْنِيَةَ بِيبَرْبَاك رَايْتَر فِي مَلْعَبِ آبِي رُودَ عَامَ أَلْفٍ وَ تِسْعَمِئَةٍ وَ سِتَّةٍ وَ سِتِّينَ لِلْبَيْعِ فِي مَزَادٍ عَلَنِيٍّ الْيَوْمَ الْأَحَدَ لِلْأَشْيَاءِ التَّذْكَارِيَّةِ الْمُتَعَلِّقَةِ بِمُوسِيقَى الرُّوك آنْد رُول فِي لُنْدُنَ
# 7                                                                                                                                                                                                                                                                                                 أُعْلِنَ يَوْمَ الْثَالثَ عَشَرْ مِنْ أُكْتُوبَرْ تِشْرِينَ الْأَوَّلِ أَلْفَيْنِ وَ سِتَّةَ عَشَرْ عَنْ فَوْزِ بُوب ديلان بِجَائِزَةِ نُوبِلَ لِلْآدَابِ فِي قَرَارٍ اعْتُبِرَ مُفَاجِئًا
# 8                                                                                                                                                                                                                                                                     سَجَّلَت الدَّوْرَةُ الخَامِسة وَالثَّلَاثِينَ لِمَعْرِضِ الشَّارِقَةِ الدَّوْلِيِّ لِلْكِتَابِ الَّتِي أُسْدِلَ السِّتارُ عَلَيْهَا يَوْمَ السَّبْتِ رَقْمًا قِيَاسِيًّا فِي عَدَدِ الزُّوَارِ وَحَجْمِ الْمَبِيعَاتِ
# 10                                                                                                                                                                                                                                                                                                                                                        وَذَهَبَتْ أَبْحَاثٌ أُخْرَى إِلَى أنَّ السَّبَبَ قَدْ يَكُونُ امْتِصَاصَ الْمُحِيطَاتِ الْعَمِيقَةِ لِلْمَزِيدِ مِنَ الْحَرَارَةِ
# 21   فَعِنْدَ إنْشَاءِ الْأُمَمِ الْمُتَّحِدَةِ عَامَ أَلْفٍ وَ تِسْعَمِئَةٍ وَ خَمْسَةٍ وَ أَرْبَعينْ اعْتَمَدَتِ الْمُنَظَّمَةُ الدَّوْلِيَّةُ خَمْسَ لُغَاتٍ حَيَّةٍ هِيَ الْإسْبَانِيَّةُ وَالْإنْجِلِيزِيَّةُ وَالرُّوسِيَّةُ وَالصِّينِيَّةُ وَالْفَرَنْسِيَّةُ بِحَيْثُ تَكُونُ لُغَاتِ تَوْثِيقِ الْمَحَاضِرِ الرَّسْمِيَّةِ وَأوْرَاقِ الْعَمَلِ أثْنَاءَ الاجْتِمَاعَاتِ وَتُعْتَمَدُ فِي التَّرْجَمَةِ الْحَيَّةِ الْمُبَاشِرَةِ أثْنَاءَ الْمُؤْتَمَرَاتِ تَحَدُّثًا وَكِتَابَةً
# 28                                                                                                                                                           مَعْرِضٌ أُوزْبَكِيٌّ فِي قَطَر مِنْ كُنُوزِ الْمَعْرِفَةِ إِلَى اللَّوْحَاتِ الْفَنِّيَّةِ وَالْمَنْحُوتَاتِ وَالْمُجَوْهَرَاتِ تَتَنَوَّعُ ذَخِيرَةُ مَعْرِضِ أُوزْبَكِسْتَانَ الْفَنِيِّ الَّذِي افْتُتِحَ فِي الدَّوْحَةِ مَطْلَعَ الْأُسْبُوعِ وَيَسْتَقْبِلُ الزُّوَّارَ حَتَّى السَادِسَ عَشَرْ مِنَ الشَّهْرِ الْجَارِي
# 41                                                      بِمُشَارَكَةِ اثْنينٍ وَ سِتِّينَ فِيلْمًا مِنْ تِسْعَةَعَشْرَةَ دَوْلَةً أُورُوبِّيَّة وَالْبَلَدِ الْمُضِيف مِصْر انْطَلَقَتْ فَعَّالِيَّاتُ الدَّوْرَةِ الثَّانِيَةِ مِنْ مِهْرَجَانِ الْأُقْصُرِ لِلسِّينَمَا الْمِصْرِيَّةِ وَالْأُورُوبِّيَّةِ وَتَحْضُرُ السِّينَمَا الْأَلْمَانِيَّةُ ضَيْفَ شَرَفْ عَلَى الْمِهْرَجَانِ الَّذِي يُفْتَتَحُ بِالْفِيلْمِ الْمِصْرِيِّ الْجَدِيدْ لَا مُؤَاخَذَة لِلْمُخْرِجْ عَمْرو سَلَامَة
# 43                                                                                                                                                                                                                                                                                                                                    لِنَيْلِ الدُّكْتُورَاه فِي أُصُولِ الفِقْهِ بَعْدَ أَيَّامٍ مِنْ نَيْلِهِ دَرَجَةَ المَاجِسْتِير مِنْ جَامِعَةِ أَبُودِيسَ فِي القُدْسِ المُحْتَلَّةِ
# 48                                                                                                                                                                                                                                                                                                       سَبْعِينِيٌّ فِلَسْطِينِيٌّ يَسْتَعِدُّ لِلدُّكْتُورَاه يَتَطَلَّعُ الحَاجُّ تَوفِيق مَحَامِيد سَبْعُونَ عَامًا مِنْ سُكَّانِ بَلْدَةِ أُمِّ الفَحْمِ بِالدَّاخِلِ الفِلَسْطِينِيِّ
# 50                                                                                   إنَّهُ يَوْمٌ يَسْتَرْجِعُ فِيهِ الشَّبَابُ التَّضْحِيَاتِ الَّتِي بَذَلَتْهَا أُسَرُهُمْ مِنْ أجْلِهِمْ وَيُفَكِّرُونَ فِي نَوْعِ التَّضْحِيَاتِ الَّتِي سَيُقَدِّمُونَهَا لِأُسَرِهِمْ وَيُدْرِكُونَ أنَّ الْمَوْقِعَ الْكَبِيرَ الَّذِي تَحْتَلُّهُ الْأُسْرَةُ لَا يَعْنِي أنَّ الْعَمَلَ يَجِبُ أنْ يَأْتِيَ فِي الْمَرْتَبَةِ الثَّانِيَةِ بَلْ إنَّ الْحَيَاةَ تَحْتَاجُ إِلَى الاثْنَيْنِ مَعًا
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                               التَّعَلُّمُ الْأُسْبُوعِيّ
# 53                                                                                                                                                                                                                                                          وَتَلَاعَبَ دِيُوكُوفِيتْش بِمُنَافِسِهِ كَمَا كَانَ يَشْتَهِي وَيُرِيدُ وَأَنْهَى الْمَجْمُوعَةَ الْأُولَى فِي وَاحِدٍ وَ ثَلَاثِينَ دَقِيقَةً بَعْدَ أَنْ اسْتَوْلَى عَلَى إرْسَالِهِ فِي الشَّوْطَيْنِ الثَّانِي وَالسَّادِسِ
# 69                                                                                                                                                                                                                                                                                                                                                                     تَنْمُو شَجَرَةُ الْأَرْغَان فِي جَنُوبِ الْمَغْرِبِ فَقَطْ وَلَا تُوجَدُ فِي أَيِّ مِنْطَقَةٍ أُخْرَى فِي الْعَالِمِ
# 71                                                                                                                                                                                                                                                                                                             دَفَعَ التَّوَتُّرُ وَالاكْتِئَابُ وَالاضْطِرَابَاتُ النَّفْسِيَّةُ الْأُخْرَى بِالْعَدِيدِ مِنَ اللُّبْنَانِيِّينَ إلَى الِالْتِحَاقِ بِدَوْرَاتٍ تَعْتَمِدُ عَلَى الضَّحِكِ
# 76                                                                                                                                                                                                                                                                                                        وَقَدْ تَمَّ تَرْحِيلُ سِتَّةِ مُعْتَقَلِينَ إِلَى أُورُوغْوَاي عَلَى مَتْنِ طَائِرَةٍ حَرْبِيَّةٍ بَعْدَ أَنْ قَضَوْا أثنتا عشرة سَنَةً مِنَ الاِحْتِجَازِ مِنْ دُونِ مُحَاكَمَةٍ
# 80                                                                                                                                                                                         وَقَدْ وَافَقَ صُنْدُوقُ النَّقْدِ الدَّوْلِيُّ مُؤَخَّرًا عَلَى إقْرَاضِ الْأُرْدُنِّ سَبْعَمِئَةٍ وَ ثَلاثَةٍ وَ عِشْرِينَ مِلْيُونَ دُولَارٍ عَلَى ثَلَاثِ سَنَوَاتٍ لِدَعْمِ نُمُوِّهِ الاقْتِصَادِيِّ وَدَعَا الْبِلَادَ إلَى تَحْسِينِ قُدْرَتِهَا التَّنَافُسِيَّةِ لِتَعْزِيزِ النُّمُوِّ
# 84                                                                                                                                                      وَفِي الشَّوْطِ الثَّانِي أَمْطَرَ الْخُضْرُ شِبَاكَ الضُّيُوفْ بِخَمْسَةِ أَهْدَافٍ أُخْرَى سَجَّلَهَا فِيغُولِي وَإبْرَاهِيمِي وَسَفِيرُ تَايْدَر وَرَشِيدُ غَزَال وَسُلَيْمَانِي ثَمَانِيَةٌ وَ أَرْبَعُونْ وَاثْنَانِ وَ سَبْعُونْ وَخَمْسَةٌ وَ سَبْعونْ وَواحِدٌ وَ ثَمَانُونْ وَالثَّالِثَةِ مِنَ الْوَقْتِ بَدَلِ الضَّائِعْ
# 88                                                                                                                                                         وَشَارَكَ فِيهِ عَدَدٌ مِنَ الْفَنَّانِينَ الْعَرَبِ وَالْأَجَانِبِ الَّذِينَ تَبَرَّعُوا بِرَيْعِ بَيْعِ لَوْحَاتِهِمْ وَأَعْمَالِهِمْ الْفَنِّيَّةِ لِجَمْعِيَّةِ إِغَاثَةِ أَطْفَالِ فِلَسْطِينَ ولَاسِيَّمَا لِبِنَاءِ الْعِيَادَةِ الطِّبِّيَّةِ الْأُولَى لِعِلَاجِ سَرَطَانِ الْأَطْفَالِ فِي قِطَاعِ غَزَّةَ الْمُحَاصَرِ
# 94                                                                                                                                                                 وَقَدْ شَرَعَ فِي هَذَا الاتِّجَاهِ بَعْدَ أَنْ أَكْمَلَ رَحْلَاتِهِ فِي طَلَبِ الْعِلْمِ فِي تُونُسَ وَمِصْرَ وَالْحِجَازِ فَأَسَّسَ مَطْبَعَةً لِلنَّشْرِ وَأَصْدَرَ عَامَ أَلْفٍ وَ ثَلَاثِمِئَةٍ وَ أَرْبَعَةَ عَشَرْ لِلْهِجْرَةِ أَلْفٍ وَ تِسْعِمِئَةٍ وَ خَمْسَةً وَ عِشْرِينَ لِلْمِيلَادْ صَحِيفَتَهُ الْأُولَى
# 97                                             قَادَ الْمُهَاجِمُ الْفَذُّ نِيمَارْ مُنْتَخَبَ الْبَرَازِيلْ لِإِحْرَازِ ذَهَبِيَّتِهِ الْأُولَى فِي تَارِيخِ مُشَارَكَاتِهِ فِي الْأَلْعَابِ الْأُولُمْبِيَّةْ بِتَسْجِيلِهِ هَدَفَ الافْتِتَاحْ فِي الْوَقْتِ الْأَصْلِيِّ أَمَامَ أَلْمَانْيَا أَحَدَ عَشَرْ ثُمَّ رَكْلَةَ التَّرْجِيحِ الْحَاسِمَةَ أَرْبَعَةٍ وَ خَمْسِينْ عَلَى مَلْعَبِ مَارَاكَانَا فِي نِهَائِيِّ مُسَابَقَةِ كُرَةِ الْقَدَمْ لِلرِّجَالْ بِأُولُمْبِيَّادِ رِيُو
# 101                                                                                                                                                                                                                                    بَعْدَ قُدُومِهِ إِلَى قَطَر عَامَ أَلْفَينْ وَ ثَلَاثَة عَمِلَ الْمُوَاطِنُ الْهِنْدِيُّ بروين كُومار سَائِقًا لِأُسْرَةٍ وَأَصْبَحَ يَقْضِي يَوْمَهُ بَيْنَ الْعَمَلِ الْمُجْهِدِ وَمُشَاهَدَةِ الْأَفْلَامِ الْهِنْدِيَّةِ وَالْأَكْلِ وَالنَّوْمِ
# 106                                                                                                                                                                                                                                                                                                                            وَيُشِيرُ التَّقْرِيرُ أَيْضًا إلَى أَنَّ وُجْهَاتٍ أُخْرَى قَدْ تَسْتَفِيدُ مِنْ هَذِهِ التَّغَيُّرَاتِ وَهِيَ الْأُرْدُنُّ وَمِصْرُ وَالْمَغْرِبُ وَتُونُسَ
# 113                                                                                         يُقَدِّرُ الْبَاحِثُونَ أنَّ سِتُّونَ مِنَ الشِّعَابِ الْمَرْجَانِيَّةِ مُهَدَّدَةٌ بِالاخْتِفَاءِ بِحُلُولِ عَامِ أَلْفينِ وَ ثَلَاثُونْ مُرْجِعِينَ أسْبَابَ ذَلِكَ إلَى الاحْتِبَاسِ الْحَرَارِيِّ وَزِيَادَةِ انْبِعَاثَاتِ غَازِ ثَانِي أُكْسِيدِ الْكَرْبُونِ الْأمْرُ الَّذِي يُهَدِّدُ مَوَاطِنَ كَثِيرٍ مِنَ الْأسْمَاكِ وَالْقِشْرِيَّاتْ وَغَيْرِهَا مِنَ الْكَائِنَاتِ الْبَحْرِيَّة
# 114                                                                                                                                                                                                                  الْأُولَى مَنْشُورَةٌ فِي أمِسْتِرْدام عَامَ أَلْفٍ وَ سُبْعُمِئَةٍ وَ ثَلاثُونْ وَالثَّانِيَةُ فِي لَنْدُن عَامَ أَلْفٍ وَ سُبْعُمِئَةٍ إِثْنَينِ وَ ثَلاثُونْ لِيُصْدِرَهُ فِي أَوَّلِ تَرْجَمَةٍ عَرَبِيَّةٍ بَعْدَ أَكْثَرَ مِنْ ثَلَاثَةِ قُرُونٍ مِنْ تَأْلِيفِهِ
# 120                                                                                                                                                                                                                                                                وَاخْتَتَمَ الْبَرَازِيلِيُّونَ مُبَارَيَاتِهِم الْإِعْدَادِيَّةَ بِالْفَوْزِ عَلَى صِرْبيَا بِهَدَفٍ وَحِيدٍ سَجَّلَهُ الْمُهَاجِمُ فريدٌ فِي الشَّوْطِ الثَّانِي مِنَ الْمُبَارَاةِ الَّتِي أُقِيمَتْ فِي سَاوْبَاوْلُو
# 121                                                                                                                                                     احْتَفَلَ الْعَالَمُ يَوْمَ الْخَمِيسِ بِالْيَوْمِ الْعَالَمِيِّ لِلْغِذَاءِ بَيْنَمَا لا تَزَالُ حَالَةُ الْأَمْنِ الْغِذَائِيِّ فِي الصُّومَالِ فِي مُسْتَوًى مُتَدَنٍّ جِدًّا وَفْقَ مُنَظَّمَاتٍ أُمَمِيَّةٍ أَطْلَقَتْ تَحْذِيرَاتِهَا مُؤَخَّرًا مِنْ أنَّ مِلْيُونَ صُومَالِيٍّ سَيُوَاجِهُونَ نَقْصًا حَادًّا فِي الْغِذَاءِ
# 122                                                                                                                                                                                                                                                                                   تُهَدِّدُ التَّغَيُّرَاتُ الْمُنَاخِيَّةُ وَزِيَادَةُ انْبِعَاثَاتِ ثَانِي أُكْسِيدِ الْكَرْبُونِ بِالْقَضَاءِ عَلَى سِتِّينَ مِنَ الشِّعَابِ الْمَرْجَانِيَّةِ بِحُلُولِ عَامِ أَلْفينِ وَ ثَلَاثُونْ
# 123                                                                                  وَيَأْتِي الْكِتَابُ ضِمْنَ سِلْسِلَةِ رُوَادِ الْمَشْرِقِ الْعَرَبِيِّ الْمُكَرَّسَةِ لِأَدَبِ رَحَلَاتِ الْأُورُوبِّيِّينَ إِلَى الْمَشْرِقِ الْعَرَبِيِّ وَهُوَ يُعَدُّ تُحْفَةً فَنِّيَّةً وَضَعَهَا عَامْ أَلْفاً وَ تُسْعُمِئَةً وَ أَرْبَعَة الرَّحَّالَةُ وَمُهَنْدِسُ التَّعْدِينْ كَالْفَرْتْ الَّذِي فُتِنَ بِإِسْبَانْيَا فَأَلَّفَ عَنْهَا وَعَنْ فُنُونِهَا سِتَّةً وَ ثَلاثُونَ كِتَابًا
# 130                                                                                                                                                                                                  وَبَلَغَتْ قِيمَةُ الاحْتِيَاطِيِّ الْأَجْنَبِيِّ فِي نِهَايَةِ أَغُسْطُسَآبَ الْمَاضِي أَلْفٌ وَ مِئَةٌ وَ سِتَّةٌ وَ سِتُّونَ مِلْيَارَ دُولَارٍ مُقَارَنَةٍ مَعَ نَحْوِ أَلْفٍ وَ أُرْبُعْمِئَةٍ وَ خَمْسَةِ عَشَرَ مِلْيَارًا فِي نِهَايَةِ الْعَامِ الْمَاضِي حَسَبَ الْبَيَانَاتْ
# 135                                                                                                                                                                                      أَجَانِبُ يَعْتَنِقُونَ الْإِسْلَامَ فِي قَطَر بَعْدَ قُدُومِهِ إِلَى قَطَر عَامَ أَلْفينِ وَ ثَلَاثَة عَمِلَ الْمُوَاطِنُ الْهِنْدِيُّ بروين كُومار سَائِقًا لِأُسْرَةٍ وَأَصْبَحَ يَقْضِي يَوْمَهُ بَيْنَ الْعَمَلِ الْمُجْهِدِ وَمُشَاهَدَةِ الْأَفْلَامِ الْهِنْدِيَّةِ وَالْأَكْلِ وَالنَّوْمِ
# 141                                                                                                                                                                                                                                                                                                    تَرَاجَعَ احْتِيَاطِيُّ النَّقْدِ الْأَجْنَبِيِّ فِي الْأُرْدُنِّ بِنَحْوِ مِئَةٍ وَ خَمْسَة مُنْذُ بِدَايَةِ الْعَامِ الْجَارِي كَمَا أَظْهَرَتْ بَيَانَاتُ الْبَنْكِ الْمَرْكَزِيِّ
# 142                                                                                                                                                                                                       اكْتَسَحَ مُنْتَخَبُ الْجَزَائِرِ ضَيْفَهُ إِثْيُوبْيَا الْوَاحِدَ وَ السَّبْعُونَ فِي الْجَوْلَةِ الثَّالِثَةِ مِنْ مُبَارَيَاتِ الْمَجْمُوعَة الْعَاشِرَةِ ضِمْنَ التَّصْفِيَاتِ الْمُؤَهِّلَةِ إلَى نِهَائِيَّاتِ أُمَمِ أَفْرِيقْيَا أَلْفَينِ وَ سَبْعَةَ عشر فِي الْغَابُونْ
# 146                                                                                                                                                             وَتَقُولُ صَحِيفَةُ هَآرِتْس الْإسْرَائِيلِيَّةُ إِنَّهُ لَا تُوجَدُ مُعْطَيَاتٌ دَقِيقَةٌ لِلْخَسَائِرِ النَّاجِمَةِ عَنْ فَرْضِ الْحُكُومَةِ لِحَظْرِ التَّجَوُّلِ مُنْذُ الرَّابِعَةَ عَشَرْ أُغُسْطُسَآب الْجَارِي لَكِنَّ التَّقْدِيرَاتِ تَتَرَاوَحُ بَيْنَ الْخَمْسَةَ و عِشْرِينَ وَ الثَّلاثِينَ مِلْيَارَ دُولَارْ
# 160                                                                                                                                                                                                                                                                                      أَحرَزَت مُنتَخَباتُ البَرازِيلِ وَأَلمانيا وَرُوسيا فَوزًا فِي مُقابَلاتِهِم الإِعدادِيَّةِ الَّتِي أُقِيمَت استِعدادًا لِنِهائِيّاتِ كَأسِ العالَم الَّتِي سَتَنطَلِقُ بَعدَ أَقَلِّ مِن أُسبُوعٍ
# 180                                                                                                                                                                                                                                                                                                                                                           حَتَّى الأَمْسِ القَرِيب كَانَ الكَثِيرُ مِنَ الأُوكْرَانِيِّينْ يُشَكِّكُونَ فِي  انْتِماءِ تَتَارِ شِبْهِ جَزِيرَةِ القُرْمِ
# 181                                                                                                                                                                                                                                                                                                                             حَذَّرَتِ الأُمَمُ المُتَّحِدَةُ مِنْ أَنَّ العَالَمَ سَيُوَاجِهُ خِلَالَ العُقُودِ المُقْبِلَةِ تَفَاقُمَ أَزْمَةٍ مُزْدَوِجَةٍ فِي المِيَاه وَالكَهْرَبَاء
# 184                                                                                                                                                                                                                                                                                                                                                                        دَخَلَتِ التِّكْنُولُوجِيَا فِي كُلِّ بَيْتٍ وَأُسْرَةٍ وَأَصْبَحَتْ تُشَكِّلُ الجُزْءَ الكَبِيرَ مِنْ حَيَاتِنَا
# 193                                                                                                                                                                                                                                                                                                         عَلَى اعْتِبَارِهَا تُسَاعِدُ عَلَى تَوْسِيعِ مَدارِكِ الأَطْفَالْ وَتَجْعَلُ مِنْهُمْ أُنَاسًا مُثَقَّفِينَ مُسْتَقْبَلًا وَمُوَاكِبِينَ لِعَصْرِ تِكْنُولُوجِيَا المَعْلُومَات
# 196                                                                                                                                                                                                                                                                                                                                                                                   فَتَحْظَى بِتَعَلُّمٍ يَمْحُو أُمِّيَّتَهَا وَيُضِيءُ لَهَا طَرِيقَ المَعْرِفَةِ وَالتِّكْنُولُوجِيَّا
# 203                                                                                                                                                                                                                                                                                                                                                كَما تُوُفِّيَتِ الرِّوَائِيَّةُ البَارِزَةُ وَالأُسْتَاذَةُ الجَامِعِيَّةُ المِصْرِيَّةُ رَضْوَى عَاشُورْ عَنْ ثَمَانِ وَسِتِّينَ عَامًا
# 206                                                                                                                                                                                                                                                                                                                                                  لَقَدْ سَاهَمَتِ التِّكْنُولُوجِيَا فِي تَقْلِيلِ النِّزَاعَاتِ الأُسَرِيَّةِ وَأَعْطَتْ لِكُلِّ فَرْدٍ نَوْعًا مِنَ الاستِقْلَالِيَّةِ
# 211                                                                                                                                                                                                                                                                                                                                                                                                                         وَذَلِكَ مُقَارَنَةً مَعَ المَحَاصِيلِ الزِّرَاعِيَّةِ الأُخْرَى
# 212                                                                                                                                                                                                                                                                                            مُلْقِيًا الضَّوءَ عَلَى قَضِيَّةِ الفِتْنَةِ الطَّائِفِيَّةِ فِي المُجْتَمَعِ المِصْرِيِّ بِأُسْلُوبٍ بَسِيطٍ مِنْ خِلَالِ عَلاقَاتِ الأَطْفَالْ فِي المَدْرَسَةِ بِزُمَيلِهِمُ المَسِيحِيِّ
# 216                                                                                                                                                                                                                                                                                                                                                                                                      هَلْ لِلصِّيَامِ تَأْثِيرٌ عَلَى عَمَلِ المُسْلِمِينَ فِي الشَّرِكَاتِ بِأُورُوبَّا
# 217                                                                                                                                                                                                                                                                                                                                                                         هُنَاكَ فِكْرَةٌ طُرِحَتْ بَادِئَ  الأَمْر بِعَقْدِ قِمَّةٍ أُورُوبِيَّةٍ فِي سَرَايِيفُو بِهَذِهِ المُنَاسَبَةِ
# 220                                                                                                                                                                                                                                                                    واختَتَمَ البَرَازِيلِيُّونَ مُبَارَياتِهِمْ الإِعْدَادِيَّةِ بِالفَوْزِ عَلَى صِرْبِيَا بِهَدَفٍ وَحِيدٍ سَجَّلَهُ المُهَاجِمُ فَريدٌ فِي الشَّوْطِ الثَّانِي مِنَ المُبَارَاةِ الَّتِي أُقِيمَتْ فِي سَاوْ بَاوْلُو
#
#     speaker_id     source   duration  sampling_rate  \
# 5    female_ab  tashkeela  21.302041          16000
# 6    female_ab  tashkeela  19.919093          16000
# 7    female_ab  tashkeela  10.465034          16000
# 8    female_ab  tashkeela  13.357098          16000
# 10   female_ab  tashkeela   7.618095          16000
# 21   female_ab  tashkeela  25.252018          16000
# 28   female_ab  tashkeela  16.506032          16000
# 41   female_ad  tashkeela  23.989070          16000
# 43   female_ad  tashkeela   8.939093          16000
# 48   female_ad  tashkeela  10.930023          16000
# 50   female_ad  tashkeela  20.520000          16000
# 52   female_ad  tashkeela   1.700000          16000
# 53   female_ad  tashkeela  12.592018          16000
# 69   female_ad  tashkeela   6.817098          16000
# 71   female_ad  tashkeela   8.623039          16000
# 76     male_aa  tashkeela  10.592018          16000
# 80     male_aa  tashkeela  17.418005          16000
# 84     male_aa  tashkeela  21.417098          16000
# 88     male_aa  tashkeela  17.036100          16000
# 94     male_aa  tashkeela  18.936009          16000
# 97     male_aa  tashkeela  25.084036          16000
# 101    male_aa  tashkeela  14.210023          16000
# 106    male_aa  tashkeela   9.298005          16000
# 113    male_ac  tashkeela  20.987075          16000
# 114    male_ac  tashkeela  14.971020          16000
# 120    male_ac  tashkeela  11.316100          16000
# 121    male_ac  tashkeela  17.254104          16000
# 122    male_ac  tashkeela  10.482086          16000
# 123    male_ac  tashkeela  22.024036          16000
# 130    male_ac  tashkeela  15.565079          16000
# 135    male_ac  tashkeela  16.542041          16000
# 141    male_ac  tashkeela   8.917007          16000
# 142    male_ac  tashkeela  14.320000          16000
# 146    male_ac  tashkeela  17.249070          16000
# 160   male_asc        asc  17.753469          16000
# 180   male_asc        asc   9.700136          16000
# 181   male_asc        asc  12.681451          16000
# 184   male_asc        asc   8.601451          16000
# 193   male_asc        asc  14.638776          16000
# 196   male_asc        asc   8.409478          16000
# 203   male_asc        asc  13.225442          16000
# 206   male_asc        asc  10.750794          16000
# 211   male_asc        asc   5.081451          16000
# 212   male_asc        asc  16.073469          16000
# 216   male_asc        asc   5.982857          16000
# 217   male_asc        asc   8.916145          16000
# 220   male_asc        asc  17.310794          16000
#
#                                                                                                audio_filepath
# 5    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00018.wav
# 6    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00022.wav
# 7    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00010.wav
# 8    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00023.wav
# 10   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00039.wav
# 21   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00015.wav
# 28   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ab_00025.wav
# 41   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00060.wav
# 43   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00062.wav
# 48   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00061.wav
# 50   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00069.wav
# 52   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00072.wav
# 53   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00051.wav
# 69   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00073.wav
# 71   /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/female_ad_00070.wav
# 76     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00092.wav
# 80     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00100.wav
# 84     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00080.wav
# 88     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00115.wav
# 94     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00093.wav
# 97     /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00086.wav
# 101    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00103.wav
# 106    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_aa_00111.wav
# 113    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00131.wav
# 114    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00124.wav
# 120    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00152.wav
# 121    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00119.wav
# 122    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00138.wav
# 123    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00118.wav
# 130    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00144.wav
# 135    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00134.wav
# 141    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00133.wav
# 142    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00122.wav
# 146    /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-1/tashkeela/tashkeela-test/male_ac_00117.wav
# 160               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0002.wav
# 180               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0022.wav
# 181               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0023.wav
# 184               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0026.wav
# 193               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0035.wav
# 196               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0038.wav
# 203               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0045.wav
# 206               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0048.wav
# 211               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0053.wav
# 212               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0054.wav
# 216               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0058.wav
# 217               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0059.wav
# 220               /home/rufael/Projects/diac-btc/data/arvoice/raw/test/part-2/asc/asc-test/ARA_NORM__0062.wav

# %%
# Test set
print(filenames[0])
info_df_0 = generate_information_report(filenames[0])
print("\nChecking the diacritics combinations in the dataset:\n")
print(
    Counter(
        [
            t[0][0]
            for l in info_df_0[info_df_0["Character"] != " "][
                "Following_diacritics"
            ].tolist()
            for t in l
            for _ in range(t[1])
        ]
    ).most_common()
)
print()

info_df_0
# Out:
# ../data/arvoice_test_metadata.json
#
# Checking the diacritics combinations in the dataset:
#
# [('', 7231), ('ARABIC FATHA', 6814), ('ARABIC KASRA', 4212), ('ARABIC SUKUN', 2848), ('ARABIC DAMMA', 1592), ('ARABIC FATHA+ARABIC SHADDA', 889), ('ARABIC KASRA+ARABIC SHADDA', 300), ('ARABIC KASRATAN', 288), ('ARABIC FATHATAN', 176), ('ARABIC DAMMA+ARABIC SHADDA', 155), ('ARABIC DAMMATAN', 61), ('ARABIC FATHATAN+ARABIC SHADDA', 30), ('ARABIC SHADDA', 11), ('ARABIC KASRATAN+ARABIC SHADDA', 8), ('ARABIC DAMMATAN+ARABIC SHADDA', 6)]
#    Character  Count  Code                                 Name Type  \
# 1              4867    32                                SPACE   Zs
# 46         (      1    40                     LEFT PARENTHESIS   Ps
# 47         )      1    41                    RIGHT PARENTHESIS   Pe
# 45         Q      1    81               LATIN CAPITAL LETTER Q   Lu
# 40         ء     75  1569                  ARABIC LETTER HAMZA   Lo
# 43         آ     32  1570  ARABIC LETTER ALEF WITH MADDA ABOVE   Lo
# 20         أ    522  1571  ARABIC LETTER ALEF WITH HAMZA ABOVE   Lo
# 44         ؤ     28  1572   ARABIC LETTER WAW WITH HAMZA ABOVE   Lo
# 33         إ    182  1573  ARABIC LETTER ALEF WITH HAMZA BELOW   Lo
# 37         ئ    146  1574   ARABIC LETTER YEH WITH HAMZA ABOVE   Lo
# 3          ا   3539  1575                   ARABIC LETTER ALEF   Lo
# 15         ب    908  1576                    ARABIC LETTER BEH   Lo
# 16         ة    904  1577            ARABIC LETTER TEH MARBUTA   Lo
# 13         ت   1120  1578                    ARABIC LETTER TEH   Lo
# 28         ث    285  1579                   ARABIC LETTER THEH   Lo
# 25         ج    329  1580                   ARABIC LETTER JEEM   Lo
# 23         ح    412  1581                    ARABIC LETTER HAH   Lo
# 30         خ    208  1582                   ARABIC LETTER KHAH   Lo
# 17         د    730  1583                    ARABIC LETTER DAL   Lo
# 36         ذ    149  1584                   ARABIC LETTER THAL   Lo
# 12         ر   1184  1585                    ARABIC LETTER REH   Lo
# 35         ز    155  1586                   ARABIC LETTER ZAIN   Lo
# 19         س    669  1587                   ARABIC LETTER SEEN   Lo
# 27         ش    290  1588                  ARABIC LETTER SHEEN   Lo
# 32         ص    199  1589                    ARABIC LETTER SAD   Lo
# 38         ض    144  1590                    ARABIC LETTER DAD   Lo
# 29         ط    211  1591                    ARABIC LETTER TAH   Lo
# 42         ظ     34  1592                    ARABIC LETTER ZAH   Lo
# 14         ع    921  1593                    ARABIC LETTER AIN   Lo
# 39         غ     91  1594                  ARABIC LETTER GHAIN   Lo
# 18         ف    688  1601                    ARABIC LETTER FEH   Lo
# 22         ق    448  1602                    ARABIC LETTER QAF   Lo
# 24         ك    408  1603                    ARABIC LETTER KAF   Lo
# 5          ل   2776  1604                    ARABIC LETTER LAM   Lo
# 8          م   1551  1605                   ARABIC LETTER MEEM   Lo
# 11         ن   1320  1606                   ARABIC LETTER NOON   Lo
# 21         ه    470  1607                    ARABIC LETTER HEH   Lo
# 9          و   1425  1608                    ARABIC LETTER WAW   Lo
# 34         ى    172  1609           ARABIC LETTER ALEF MAKSURA   Lo
# 6          ي   1893  1610                    ARABIC LETTER YEH   Lo
# 31         ً    206  1611                      ARABIC FATHATAN   Mn
# 41         ٌ     67  1612                      ARABIC DAMMATAN   Mn
# 26         ٍ    296  1613                      ARABIC KASRATAN   Mn
# 0          َ   7704  1614                         ARABIC FATHA   Mn
# 7          ُ   1748  1615                         ARABIC DAMMA   Mn
# 2          ِ   4512  1616                         ARABIC KASRA   Mn
# 10         ّ   1399  1617                        ARABIC SHADDA   Mn
# 4          ْ   2848  1618                         ARABIC SUKUN   Mn
#
#     is_diacritic  \
# 1          False
# 46         False
# 47         False
# 45         False
# 40         False
# 43         False
# 20         False
# 44         False
# 33         False
# 37         False
# 3          False
# 15         False
# 16         False
# 13         False
# 28         False
# 25         False
# 23         False
# 30         False
# 17         False
# 36         False
# 12         False
# 35         False
# 19         False
# 27         False
# 32         False
# 38         False
# 29         False
# 42         False
# 14         False
# 39         False
# 18         False
# 22         False
# 24         False
# 5          False
# 8          False
# 11         False
# 21         False
# 9          False
# 34         False
# 6          False
# 31          True
# 41          True
# 26          True
# 0           True
# 7           True
# 2           True
# 10          True
# 4           True
#
#                                                                                                                                                                                                                                                                                                                                                                                                               Following_diacritics
# 1                                                                                                                                                                                                                                                                                                                                                                   [((, ), 4865), ((ARABIC DAMMA, ُ), 1), ((ARABIC FATHA, َ), 1)]
# 46                                                                                                                                                                                                                                                                                                                                                                                                                     [((, ), 1)]
# 47                                                                                                                                                                                                                                                                                                                                                                                                                     [((, ), 1)]
# 45                                                                                                                                                                                                                                                                                                                                                                                                                     [((, ), 1)]
# 40                                                                                                                                                                                                                                                                                     [((ARABIC KASRA, ِ), 29), ((ARABIC FATHA, َ), 24), ((, ), 7), ((ARABIC DAMMA, ُ), 6), ((ARABIC FATHATAN, ً), 5), ((ARABIC KASRATAN, ٍ), 4)]
# 43                                                                                                                                                                                                                                                                                                                                                                                                                    [((, ), 32)]
# 20                                                                                                                                                                                                                                                                                                                                        [((ARABIC FATHA, َ), 379), ((, ), 73), ((ARABIC DAMMA, ُ), 58), ((ARABIC SUKUN, ْ), 12)]
# 44                                                                                                                                                                                                                                                                                                                    [((ARABIC FATHA, َ), 16), ((ARABIC DAMMA, ُ), 6), ((ARABIC SUKUN, ْ), 3), ((ARABIC KASRA, ِ), 2), ((, ), 1)]
# 33                                                                                                                                                                                                                                                                                                                                                                                          [((ARABIC KASRA, ِ), 121), ((, ), 61)]
# 37                                                                                                                                                                                                                                                                                                                                        [((ARABIC KASRA, ِ), 83), ((ARABIC FATHA, َ), 57), ((, ), 4), ((ARABIC FATHATAN, ً), 2)]
# 3                                                                                                                                                                                                                                                                                                              [((, ), 3503), ((ARABIC KASRA, ِ), 15), ((ARABIC FATHATAN, ً), 15), ((ARABIC FATHA, َ), 5), ((ARABIC SUKUN, ْ), 1)]
# 15                                                                                                     [((ARABIC KASRA, ِ), 352), ((ARABIC FATHA, َ), 326), ((ARABIC SUKUN, ْ), 87), ((, ), 59), ((ARABIC DAMMA, ُ), 56), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 9), ((ARABIC KASRATAN, ٍ), 6), ((ARABIC FATHATAN, ً), 6), ((ARABIC FATHA+ARABIC SHADDA, َّ), 5), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC DAMMATAN, ٌ), 1)]
# 16                                                                                                                                                                                                                          [((ARABIC KASRA, ِ), 392), ((ARABIC KASRATAN, ٍ), 141), ((ARABIC FATHA, َ), 102), ((ARABIC DAMMA, ُ), 98), ((, ), 66), ((ARABIC FATHATAN, ً), 65), ((ARABIC DAMMATAN, ٌ), 33), ((ARABIC SUKUN, ْ), 7)]
# 13                                                           [((ARABIC FATHA, َ), 398), ((ARABIC KASRA, ِ), 308), ((ARABIC FATHA+ARABIC SHADDA, َّ), 100), ((ARABIC SUKUN, ْ), 95), ((ARABIC DAMMA, ُ), 80), ((, ), 65), ((ARABIC KASRATAN, ٍ), 30), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 20), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 15), ((ARABIC DAMMATAN, ٌ), 7), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC SHADDA, ّ), 1)]
# 28                                                                                                                                    [((ARABIC FATHA, َ), 123), ((ARABIC FATHA+ARABIC SHADDA, َّ), 43), ((ARABIC SUKUN, ْ), 39), ((ARABIC KASRA, ِ), 32), ((ARABIC DAMMA, ُ), 32), ((, ), 9), ((ARABIC FATHATAN, ً), 3), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC DAMMATAN, ٌ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 25                                                                                                                    [((ARABIC FATHA, َ), 150), ((ARABIC KASRA, ِ), 68), ((ARABIC SUKUN, ْ), 60), ((ARABIC DAMMA, ُ), 17), ((ARABIC FATHA+ARABIC SHADDA, َّ), 15), ((, ), 14), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1), ((ARABIC KASRATAN, ٍ), 1)]
# 23                                                                                                                                    [((ARABIC FATHA, َ), 174), ((ARABIC KASRA, ِ), 80), ((ARABIC SUKUN, ْ), 75), ((ARABIC DAMMA, ُ), 42), ((, ), 24), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((ARABIC FATHATAN, ً), 4), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2), ((ARABIC KASRATAN, ٍ), 1)]
# 30                                                                                                                                                                                                                                              [((ARABIC FATHA, َ), 97), ((ARABIC SUKUN, ْ), 41), ((ARABIC KASRA, ِ), 33), ((ARABIC DAMMA, ُ), 22), ((, ), 11), ((ARABIC FATHA+ARABIC SHADDA, َّ), 3), ((ARABIC DAMMATAN, ٌ), 1)]
# 17                                                          [((ARABIC FATHA, َ), 252), ((ARABIC KASRA, ِ), 171), ((ARABIC DAMMA, ُ), 80), ((ARABIC SUKUN, ْ), 58), ((ARABIC FATHA+ARABIC SHADDA, َّ), 52), ((, ), 48), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 20), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 17), ((ARABIC KASRATAN, ٍ), 15), ((ARABIC FATHATAN, ً), 8), ((ARABIC DAMMATAN, ٌ), 5), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 4)]
# 36                                                                                                                                                                   [((ARABIC KASRA, ِ), 50), ((ARABIC FATHA, َ), 48), ((, ), 22), ((ARABIC DAMMA, ُ), 11), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC SUKUN, ْ), 6), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC SHADDA, ّ), 1), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1)]
# 12                                                                                                   [((ARABIC FATHA, َ), 432), ((ARABIC KASRA, ِ), 272), ((ARABIC SUKUN, ْ), 193), ((, ), 96), ((ARABIC DAMMA, ُ), 95), ((ARABIC FATHA+ARABIC SHADDA, َّ), 48), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 18), ((ARABIC KASRATAN, ٍ), 12), ((ARABIC FATHATAN, ً), 11), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC DAMMATAN, ٌ), 1)]
# 35                                                                                                                                     [((ARABIC KASRA, ِ), 53), ((ARABIC FATHA, َ), 52), ((ARABIC DAMMA, ُ), 14), ((, ), 12), ((ARABIC SUKUN, ْ), 10), ((ARABIC FATHA+ARABIC SHADDA, َّ), 5), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 4), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 3), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC FATHATAN, ً), 1)]
# 19                                                                                                                               [((ARABIC FATHA, َ), 205), ((ARABIC SUKUN, ْ), 180), ((ARABIC KASRA, ِ), 149), ((, ), 38), ((ARABIC FATHA+ARABIC SHADDA, َّ), 29), ((ARABIC DAMMA, ُ), 26), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 20), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 18), ((ARABIC FATHATAN, ً), 2), ((ARABIC KASRATAN, ٍ), 2)]
# 27                                                                                                                                                                                         [((ARABIC FATHA, َ), 127), ((ARABIC SUKUN, ْ), 60), ((ARABIC FATHA+ARABIC SHADDA, َّ), 38), ((, ), 23), ((ARABIC KASRA, ِ), 22), ((ARABIC DAMMA, ُ), 12), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 7), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 32                                                                           [((ARABIC FATHA, َ), 51), ((ARABIC SUKUN, ْ), 44), ((ARABIC KASRA, ِ), 34), ((ARABIC DAMMA, ُ), 20), ((, ), 16), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 14), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC FATHATAN, ً), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 38                                                                                                                                                  [((ARABIC KASRA, ِ), 54), ((ARABIC FATHA, َ), 41), ((ARABIC DAMMA, ُ), 18), ((ARABIC SUKUN, ْ), 10), ((, ), 7), ((ARABIC FATHATAN, ً), 6), ((ARABIC FATHA+ARABIC SHADDA, َّ), 5), ((ARABIC DAMMATAN, ٌ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC KASRATAN, ٍ), 1)]
# 29                                                                                                         [((ARABIC FATHA, َ), 74), ((ARABIC KASRA, ِ), 55), ((ARABIC SUKUN, ْ), 28), ((ARABIC DAMMA, ُ), 16), ((ARABIC FATHA+ARABIC SHADDA, َّ), 10), ((, ), 10), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 8), ((ARABIC KASRATAN, ٍ), 4), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 3), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC FATHATAN, ً), 1)]
# 42                                                                                                                                                                                                                                                              [((ARABIC FATHA, َ), 11), ((ARABIC KASRA, ِ), 8), ((ARABIC FATHA+ARABIC SHADDA, َّ), 7), ((, ), 4), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC SUKUN, ْ), 2)]
# 14                                                                                                                                                                                                                [((ARABIC FATHA, َ), 534), ((ARABIC SUKUN, ْ), 130), ((ARABIC KASRA, ِ), 125), ((ARABIC DAMMA, ُ), 66), ((, ), 55), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC FATHA+ARABIC SHADDA, َّ), 3), ((ARABIC FATHATAN, ً), 3)]
# 39                                                                                                                                                                                                                                                                                                                  [((ARABIC FATHA, َ), 45), ((ARABIC SUKUN, ْ), 19), ((ARABIC KASRA, ِ), 12), ((ARABIC DAMMA, ُ), 8), ((, ), 7)]
# 18                                                                                                                                              [((ARABIC KASRA, ِ), 300), ((ARABIC FATHA, َ), 230), ((, ), 47), ((ARABIC SUKUN, ْ), 44), ((ARABIC KASRATAN, ٍ), 28), ((ARABIC DAMMA, ُ), 27), ((ARABIC FATHATAN, ً), 7), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1)]
# 22                                                                                                                                    [((ARABIC FATHA, َ), 205), ((ARABIC KASRA, ِ), 78), ((ARABIC SUKUN, ْ), 68), ((ARABIC DAMMA, ُ), 47), ((, ), 30), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC FATHATAN, ً), 4), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 3), ((ARABIC KASRATAN, ٍ), 3), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1)]
# 24                                                                                                                                    [((ARABIC FATHA, َ), 145), ((ARABIC KASRA, ِ), 72), ((ARABIC DAMMA, ُ), 70), ((ARABIC SUKUN, ْ), 64), ((, ), 37), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 9), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC FATHATAN, ً), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 5                                                           [((, ), 915), ((ARABIC SUKUN, ْ), 788), ((ARABIC FATHA, َ), 460), ((ARABIC KASRA, ِ), 382), ((ARABIC FATHA+ARABIC SHADDA, َّ), 90), ((ARABIC DAMMA, ُ), 74), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 25), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 19), ((ARABIC KASRATAN, ٍ), 13), ((ARABIC FATHATAN, ً), 7), ((ARABIC SHADDA, ّ), 2), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1)]
# 8                                                                                                    [((ARABIC FATHA, َ), 517), ((ARABIC KASRA, ِ), 441), ((ARABIC DAMMA, ُ), 320), ((ARABIC SUKUN, ْ), 125), ((, ), 83), ((ARABIC FATHA+ARABIC SHADDA, َّ), 22), ((ARABIC KASRATAN, ٍ), 15), ((ARABIC FATHATAN, ً), 13), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 8), ((ARABIC DAMMATAN, ٌ), 5), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2)]
# 11                [((ARABIC FATHA, َ), 397), ((ARABIC SUKUN, ْ), 338), ((ARABIC KASRA, ِ), 246), ((, ), 128), ((ARABIC DAMMA, ُ), 87), ((ARABIC FATHA+ARABIC SHADDA, َّ), 84), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 20), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC FATHATAN, ً), 5), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 21                                                                                                                                                                                                                                [((ARABIC FATHA, َ), 180), ((ARABIC KASRA, ِ), 126), ((ARABIC DAMMA, ُ), 83), ((, ), 49), ((ARABIC SUKUN, ْ), 30), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 9                                                                                                                                   [((ARABIC FATHA, َ), 675), ((, ), 514), ((ARABIC SUKUN, ْ), 139), ((ARABIC KASRA, ِ), 39), ((ARABIC FATHA+ARABIC SHADDA, َّ), 26), ((ARABIC DAMMA, ُ), 14), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 10), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 5), ((ARABIC FATHATAN, ً), 2), ((ARABIC SHADDA, ّ), 1)]
# 34                                                                                                                                                                                                                                                                                                                                                                                        [((, ), 171), ((ARABIC FATHATAN, ً), 1)]
# 6   [((, ), 987), ((ARABIC FATHA, َ), 282), ((ARABIC FATHA+ARABIC SHADDA, َّ), 260), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 102), ((ARABIC SUKUN, ْ), 92), ((ARABIC DAMMA, ُ), 87), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 37), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 19), ((ARABIC KASRA, ِ), 8), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 6), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 6), ((ARABIC SHADDA, ّ), 6), ((ARABIC FATHATAN, ً), 1)]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 41                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 26                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 0                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 7                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 10                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               []

# %%
# Train set
print(filenames[1])
info_df_1 = generate_information_report(filenames[1])
print("\nChecking the diacritics combinations in the dataset:\n")
print(
    Counter(
        [
            t[0][0]
            for l in info_df_1[info_df_1["Character"] != " "][
                "Following_diacritics"
            ].tolist()
            for t in l
            for _ in range(t[1])
        ]
    ).most_common()
)
print()

info_df_1
# Out:
# ../data/arvoice_train_metadata.json
#
# Checking the diacritics combinations in the dataset:
#
# [('', 105490), ('ARABIC FATHA', 59812), ('ARABIC KASRA', 39828), ('ARABIC SUKUN', 27018), ('ARABIC DAMMA', 14903), ('ARABIC FATHA+ARABIC SHADDA', 8682), ('ARABIC KASRA+ARABIC SHADDA', 2939), ('ARABIC KASRATAN', 2444), ('ARABIC FATHATAN', 2150), ('ARABIC DAMMA+ARABIC SHADDA', 1424), ('ARABIC DAMMATAN', 786), ('ARABIC SHADDA', 303), ('ARABIC KASRATAN+ARABIC SHADDA', 189), ('ARABIC FATHATAN+ARABIC SHADDA', 157), ('ARABIC DAMMATAN+ARABIC SHADDA', 97), ('ARABIC KASRA+ARABIC KASRA', 4), ('ARABIC KASRA+ARABIC SUKUN', 1), ('ARABIC FATHA+ARABIC KASRA', 1)]
#    Character  Count  Code                                 Name Type  \
# 1             50882    32                                SPACE   Zs
# 49         "      4    34                       QUOTATION MARK   Po
# 51         -      2    45                         HYPHEN-MINUS   Pd
# 47         ،      5  1548                         ARABIC COMMA   Po
# 40         ء    915  1569                  ARABIC LETTER HAMZA   Lo
# 44         آ    278  1570  ARABIC LETTER ALEF WITH MADDA ABOVE   Lo
# 21         أ   5707  1571  ARABIC LETTER ALEF WITH HAMZA ABOVE   Lo
# 43         ؤ    344  1572   ARABIC LETTER WAW WITH HAMZA ABOVE   Lo
# 30         إ   2436  1573  ARABIC LETTER ALEF WITH HAMZA BELOW   Lo
# 39         ئ   1242  1574   ARABIC LETTER YEH WITH HAMZA ABOVE   Lo
# 3          ا  39199  1575                   ARABIC LETTER ALEF   Lo
# 14         ب   9403  1576                    ARABIC LETTER BEH   Lo
# 16         ة   8922  1577            ARABIC LETTER TEH MARBUTA   Lo
# 13         ت  12059  1578                    ARABIC LETTER TEH   Lo
# 34         ث   1936  1579                   ARABIC LETTER THEH   Lo
# 25         ج   3739  1580                   ARABIC LETTER JEEM   Lo
# 23         ح   4777  1581                    ARABIC LETTER HAH   Lo
# 33         خ   2135  1582                   ARABIC LETTER KHAH   Lo
# 17         د   7738  1583                    ARABIC LETTER DAL   Lo
# 37         ذ   1628  1584                   ARABIC LETTER THAL   Lo
# 12         ر  12833  1585                    ARABIC LETTER REH   Lo
# 36         ز   1697  1586                   ARABIC LETTER ZAIN   Lo
# 19         س   6467  1587                   ARABIC LETTER SEEN   Lo
# 26         ش   2787  1588                  ARABIC LETTER SHEEN   Lo
# 27         ص   2675  1589                    ARABIC LETTER SAD   Lo
# 35         ض   1874  1590                    ARABIC LETTER DAD   Lo
# 29         ط   2510  1591                    ARABIC LETTER TAH   Lo
# 42         ظ    708  1592                    ARABIC LETTER ZAH   Lo
# 15         ع   9280  1593                    ARABIC LETTER AIN   Lo
# 38         غ   1251  1594                  ARABIC LETTER GHAIN   Lo
# 46         ـ     26  1600                       ARABIC TATWEEL   Lm
# 18         ف   6940  1601                    ARABIC LETTER FEH   Lo
# 22         ق   5411  1602                    ARABIC LETTER QAF   Lo
# 24         ك   4738  1603                    ARABIC LETTER KAF   Lo
# 4          ل  30913  1604                    ARABIC LETTER LAM   Lo
# 7          م  16835  1605                   ARABIC LETTER MEEM   Lo
# 11         ن  13648  1606                   ARABIC LETTER NOON   Lo
# 20         ه   6279  1607                    ARABIC LETTER HEH   Lo
# 9          و  14236  1608                    ARABIC LETTER WAW   Lo
# 32         ى   2297  1609           ARABIC LETTER ALEF MAKSURA   Lo
# 6          ي  20313  1610                    ARABIC LETTER YEH   Lo
# 53         ٠      1  1632              ARABIC-INDIC DIGIT ZERO   Nd
# 52         ٨      1  1640             ARABIC-INDIC DIGIT EIGHT   Nd
# 50         ڤ      2  1700                    ARABIC LETTER VEH   Lo
# 48         ی      4  1740              ARABIC LETTER FARSI YEH   Lo
# 45         ​     32  8203                     ZERO WIDTH SPACE   Cf
# 31         ً   2307  1611                      ARABIC FATHATAN   Mn
# 41         ٌ    883  1612                      ARABIC DAMMATAN   Mn
# 28         ٍ   2633  1613                      ARABIC KASRATAN   Mn
# 0          َ  68498  1614                         ARABIC FATHA   Mn
# 8          ُ  16327  1615                         ARABIC DAMMA   Mn
# 2          ِ  42779  1616                         ARABIC KASRA   Mn
# 10         ّ  13791  1617                        ARABIC SHADDA   Mn
# 5          ْ  27021  1618                         ARABIC SUKUN   Mn
# 54         ٰ      1  1648       ARABIC LETTER SUPERSCRIPT ALEF   Mn
#
#     is_diacritic  \
# 1          False
# 49         False
# 51         False
# 47         False
# 40         False
# 44         False
# 21         False
# 43         False
# 30         False
# 39         False
# 3          False
# 14         False
# 16         False
# 13         False
# 34         False
# 25         False
# 23         False
# 33         False
# 17         False
# 37         False
# 12         False
# 36         False
# 19         False
# 26         False
# 27         False
# 35         False
# 29         False
# 42         False
# 15         False
# 38         False
# 46         False
# 18         False
# 22         False
# 24         False
# 4          False
# 7          False
# 11         False
# 20         False
# 9          False
# 32         False
# 6          False
# 53         False
# 52         False
# 50         False
# 48         False
# 45         False
# 31          True
# 41          True
# 28          True
# 0           True
# 8           True
# 2           True
# 10          True
# 5           True
# 54          True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Following_diacritics
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                               [((, ), 50875), ((ARABIC FATHA, َ), 3), ((ARABIC KASRA, ِ), 2), ((ARABIC SUKUN, ْ), 2)]
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 4)]
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 2)]
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 5)]
# 40                                                                                                                                                                                                                                                                                                                               [((ARABIC KASRA, ِ), 339), ((ARABIC FATHA, َ), 217), ((, ), 203), ((ARABIC DAMMA, ُ), 81), ((ARABIC KASRATAN, ٍ), 36), ((ARABIC FATHATAN, ً), 27), ((ARABIC DAMMATAN, ٌ), 11), ((ARABIC SUKUN, ْ), 1)]
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [((, ), 277), ((ARABIC FATHA, َ), 1)]
# 21                                                                                                                                                                                                                                                                                          [((ARABIC FATHA, َ), 3358), ((, ), 1736), ((ARABIC DAMMA, ُ), 444), ((ARABIC SUKUN, ْ), 160), ((ARABIC SHADDA, ّ), 4), ((ARABIC FATHATAN, ً), 2), ((ARABIC KASRA, ِ), 1), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1), ((ARABIC KASRATAN, ٍ), 1)]
# 43                                                                                                                                                                                                                                                                                                                                                                                                                     [((ARABIC FATHA, َ), 121), ((, ), 98), ((ARABIC DAMMA, ُ), 61), ((ARABIC SUKUN, ْ), 58), ((ARABIC KASRA, ِ), 6)]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                               [((ARABIC KASRA, ِ), 1462), ((, ), 972), ((ARABIC FATHA, َ), 1), ((ARABIC KASRA+ARABIC KASRA, ِِ), 1)]
# 39                                                                                                                                                                                                                                                                                                                                                            [((ARABIC KASRA, ِ), 758), ((ARABIC FATHA, َ), 228), ((, ), 211), ((ARABIC SUKUN, ْ), 19), ((ARABIC DAMMA, ُ), 16), ((ARABIC FATHATAN, ً), 6), ((ARABIC KASRATAN, ٍ), 4)]
# 3                                                                                                                                                                                                                                                                                                                                                [((, ), 38278), ((ARABIC FATHATAN, ً), 804), ((ARABIC KASRA, ِ), 78), ((ARABIC FATHA, َ), 27), ((ARABIC SUKUN, ْ), 6), ((ARABIC SHADDA, ّ), 5), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1)]
# 14                                         [((ARABIC KASRA, ِ), 3262), ((ARABIC FATHA, َ), 2603), ((, ), 2017), ((ARABIC SUKUN, ْ), 594), ((ARABIC DAMMA, ُ), 592), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 79), ((ARABIC FATHA+ARABIC SHADDA, َّ), 78), ((ARABIC FATHATAN, ً), 67), ((ARABIC KASRATAN, ٍ), 49), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 20), ((ARABIC DAMMATAN, ٌ), 19), ((ARABIC SHADDA, ّ), 13), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 5), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 3), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2)]
# 16                                                                                                                                                                                                                                                                                                                         [((ARABIC KASRA, ِ), 3897), ((, ), 1651), ((ARABIC KASRATAN, ٍ), 996), ((ARABIC DAMMA, ُ), 881), ((ARABIC FATHA, َ), 611), ((ARABIC FATHATAN, ً), 543), ((ARABIC DAMMATAN, ٌ), 338), ((ARABIC SUKUN, ْ), 5)]
# 13                                       [((ARABIC FATHA, َ), 3769), ((ARABIC KASRA, ِ), 2740), ((, ), 2481), ((ARABIC SUKUN, ْ), 854), ((ARABIC FATHA+ARABIC SHADDA, َّ), 808), ((ARABIC DAMMA, ُ), 738), ((ARABIC KASRATAN, ٍ), 346), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 155), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 83), ((ARABIC DAMMATAN, ٌ), 59), ((ARABIC SHADDA, ّ), 16), ((ARABIC FATHATAN, ً), 6), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 2), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1)]
# 34                                                                                                                                                                            [((ARABIC FATHA, َ), 580), ((, ), 351), ((ARABIC KASRA, ِ), 271), ((ARABIC FATHA+ARABIC SHADDA, َّ), 254), ((ARABIC DAMMA, ُ), 218), ((ARABIC SUKUN, ْ), 182), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 35), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 16), ((ARABIC KASRATAN, ٍ), 11), ((ARABIC FATHATAN, ً), 8), ((ARABIC DAMMATAN, ٌ), 8), ((ARABIC SHADDA, ّ), 2)]
# 25                                                                                                                                  [((ARABIC FATHA, َ), 1380), ((, ), 783), ((ARABIC KASRA, ِ), 587), ((ARABIC SUKUN, ْ), 524), ((ARABIC DAMMA, ُ), 302), ((ARABIC FATHA+ARABIC SHADDA, َّ), 94), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 28), ((ARABIC FATHATAN, ً), 13), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 11), ((ARABIC KASRATAN, ٍ), 9), ((ARABIC DAMMATAN, ٌ), 6), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1), ((ARABIC SHADDA, ّ), 1)]
# 23                                                                                                                                                                           [((ARABIC FATHA, َ), 1803), ((, ), 993), ((ARABIC SUKUN, ْ), 754), ((ARABIC KASRA, ِ), 691), ((ARABIC DAMMA, ُ), 369), ((ARABIC FATHA+ARABIC SHADDA, َّ), 58), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 48), ((ARABIC KASRATAN, ٍ), 29), ((ARABIC FATHATAN, ً), 15), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 11), ((ARABIC DAMMATAN, ٌ), 4), ((ARABIC SHADDA, ّ), 2)]
# 33                                                                                                                                                                                                        [((ARABIC FATHA, َ), 769), ((ARABIC SUKUN, ْ), 447), ((, ), 432), ((ARABIC KASRA, ِ), 306), ((ARABIC DAMMA, ُ), 129), ((ARABIC FATHA+ARABIC SHADDA, َّ), 20), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 11), ((ARABIC DAMMATAN, ٌ), 8), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 8), ((ARABIC KASRATAN, ٍ), 3), ((ARABIC FATHATAN, ً), 2)]
# 17                                   [((ARABIC FATHA, َ), 2048), ((ARABIC KASRA, ِ), 1708), ((, ), 1671), ((ARABIC DAMMA, ُ), 635), ((ARABIC FATHA+ARABIC SHADDA, َّ), 493), ((ARABIC SUKUN, ْ), 470), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 234), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 152), ((ARABIC KASRATAN, ٍ), 125), ((ARABIC FATHATAN, ً), 93), ((ARABIC DAMMATAN, ٌ), 44), ((ARABIC SHADDA, ّ), 39), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 13), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 12), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1)]
# 37                                                                                                                                                                                 [((ARABIC KASRA, ِ), 498), ((ARABIC FATHA, َ), 463), ((, ), 408), ((ARABIC DAMMA, ُ), 82), ((ARABIC SUKUN, ْ), 78), ((ARABIC FATHA+ARABIC SHADDA, َّ), 62), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 25), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC SHADDA, ّ), 2), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC FATHATAN, ً), 1), ((ARABIC KASRATAN, ٍ), 1)]
# 12                                   [((ARABIC FATHA, َ), 3919), ((ARABIC KASRA, ِ), 2835), ((, ), 2652), ((ARABIC SUKUN, ْ), 1390), ((ARABIC DAMMA, ُ), 933), ((ARABIC FATHA+ARABIC SHADDA, َّ), 383), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 208), ((ARABIC KASRATAN, ٍ), 178), ((ARABIC FATHATAN, ً), 124), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 110), ((ARABIC DAMMATAN, ٌ), 75), ((ARABIC SHADDA, ّ), 13), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 6), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 5), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2)]
# 36                                                   [((ARABIC FATHA, َ), 463), ((ARABIC KASRA, ِ), 425), ((, ), 333), ((ARABIC SUKUN, ْ), 169), ((ARABIC DAMMA, ُ), 137), ((ARABIC FATHA+ARABIC SHADDA, َّ), 71), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 46), ((ARABIC FATHATAN, ً), 18), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 14), ((ARABIC KASRATAN, ٍ), 7), ((ARABIC DAMMATAN, ٌ), 5), ((ARABIC SHADDA, ّ), 4), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2), ((ARABIC KASRA+ARABIC KASRA, ِِ), 2), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 19                                                                                                                           [((ARABIC FATHA, َ), 1556), ((ARABIC SUKUN, ْ), 1552), ((, ), 1276), ((ARABIC KASRA, ِ), 1101), ((ARABIC DAMMA, ُ), 299), ((ARABIC FATHA+ARABIC SHADDA, َّ), 298), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 173), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 155), ((ARABIC KASRATAN, ٍ), 29), ((ARABIC FATHATAN, ً), 13), ((ARABIC DAMMATAN, ٌ), 6), ((ARABIC SHADDA, ّ), 6), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 3)]
# 26                                                                                                                                                               [((ARABIC FATHA, َ), 953), ((, ), 552), ((ARABIC SUKUN, ْ), 485), ((ARABIC FATHA+ARABIC SHADDA, َّ), 345), ((ARABIC KASRA, ِ), 245), ((ARABIC DAMMA, ُ), 93), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 62), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 38), ((ARABIC SHADDA, ّ), 6), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 3), ((ARABIC DAMMATAN, ٌ), 3), ((ARABIC KASRATAN, ٍ), 2)]
# 27                                                                                     [((ARABIC FATHA, َ), 633), ((, ), 507), ((ARABIC SUKUN, ْ), 442), ((ARABIC KASRA, ِ), 405), ((ARABIC FATHA+ARABIC SHADDA, َّ), 209), ((ARABIC DAMMA, ُ), 199), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 159), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 55), ((ARABIC KASRATAN, ٍ), 27), ((ARABIC FATHATAN, ً), 18), ((ARABIC DAMMATAN, ٌ), 10), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 5), ((ARABIC SHADDA, ّ), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 3)]
# 35                                                                                                                                                                                                     [((ARABIC FATHA, َ), 527), ((ARABIC KASRA, ِ), 514), ((, ), 352), ((ARABIC DAMMA, ُ), 179), ((ARABIC SUKUN, ْ), 121), ((ARABIC FATHA+ARABIC SHADDA, َّ), 66), ((ARABIC FATHATAN, ً), 50), ((ARABIC KASRATAN, ٍ), 21), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 18), ((ARABIC DAMMATAN, ٌ), 17), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 9)]
# 29                                                                                                                                                                           [((ARABIC FATHA, َ), 810), ((ARABIC KASRA, ِ), 507), ((, ), 465), ((ARABIC SUKUN, ْ), 254), ((ARABIC FATHA+ARABIC SHADDA, َّ), 175), ((ARABIC DAMMA, ُ), 148), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 82), ((ARABIC KASRATAN, ٍ), 39), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 11), ((ARABIC FATHATAN, ً), 11), ((ARABIC DAMMATAN, ٌ), 6), ((ARABIC SHADDA, ّ), 2)]
# 42                                                                                                                                                                 [((ARABIC FATHA, َ), 226), ((, ), 168), ((ARABIC KASRA, ِ), 98), ((ARABIC FATHA+ARABIC SHADDA, َّ), 86), ((ARABIC SUKUN, ْ), 56), ((ARABIC DAMMA, ُ), 39), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 16), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 7), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC FATHATAN, ً), 4), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC DAMMATAN, ٌ), 1)]
# 15                                                                                                                                                                                                                 [((ARABIC FATHA, َ), 4111), ((, ), 1887), ((ARABIC KASRA, ِ), 1249), ((ARABIC SUKUN, ْ), 1189), ((ARABIC DAMMA, ُ), 694), ((ARABIC KASRATAN, ٍ), 52), ((ARABIC FATHA+ARABIC SHADDA, َّ), 44), ((ARABIC FATHATAN, ً), 40), ((ARABIC DAMMATAN, ٌ), 9), ((ARABIC SHADDA, ّ), 4), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 38                                                                                                                                                                                                                                                                                                                      [((ARABIC FATHA, َ), 492), ((ARABIC SUKUN, ْ), 285), ((, ), 259), ((ARABIC KASRA, ِ), 124), ((ARABIC DAMMA, ُ), 82), ((ARABIC FATHA+ARABIC SHADDA, َّ), 6), ((ARABIC SHADDA, ّ), 2), ((ARABIC KASRATAN, ٍ), 1)]
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [((, ), 25), ((ARABIC KASRA, ِ), 1)]
# 18                                                                                                                                                       [((ARABIC KASRA, ِ), 2677), ((ARABIC FATHA, َ), 1807), ((, ), 1451), ((ARABIC SUKUN, ْ), 436), ((ARABIC DAMMA, ُ), 350), ((ARABIC KASRATAN, ٍ), 86), ((ARABIC FATHA+ARABIC SHADDA, َّ), 43), ((ARABIC FATHATAN, ً), 27), ((ARABIC DAMMATAN, ٌ), 22), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 20), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 19), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2)]
# 22                                                                                                                              [((ARABIC FATHA, َ), 2008), ((, ), 1196), ((ARABIC KASRA, ِ), 896), ((ARABIC SUKUN, ْ), 628), ((ARABIC DAMMA, ُ), 436), ((ARABIC FATHA+ARABIC SHADDA, َّ), 86), ((ARABIC FATHATAN, ً), 42), ((ARABIC KASRATAN, ٍ), 36), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 30), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 23), ((ARABIC DAMMATAN, ٌ), 18), ((ARABIC SHADDA, ّ), 10), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 2)]
# 24                                                                                                                                 [((ARABIC FATHA, َ), 1535), ((, ), 1208), ((ARABIC KASRA, ِ), 719), ((ARABIC DAMMA, ُ), 543), ((ARABIC SUKUN, ْ), 502), ((ARABIC FATHA+ARABIC SHADDA, َّ), 111), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 80), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 13), ((ARABIC KASRATAN, ٍ), 8), ((ARABIC FATHATAN, ً), 7), ((ARABIC SHADDA, ّ), 7), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 4), ((ARABIC DAMMATAN, ٌ), 1)]
# 4                                    [((, ), 11476), ((ARABIC SUKUN, ْ), 8993), ((ARABIC FATHA, َ), 4514), ((ARABIC KASRA, ِ), 3777), ((ARABIC FATHA+ARABIC SHADDA, َّ), 837), ((ARABIC DAMMA, ُ), 699), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 180), ((ARABIC KASRATAN, ٍ), 136), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 127), ((ARABIC FATHATAN, ً), 96), ((ARABIC DAMMATAN, ٌ), 32), ((ARABIC SHADDA, ّ), 27), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 8), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 6), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 5)]
# 7                                      [((ARABIC FATHA, َ), 4781), ((ARABIC KASRA, ِ), 3630), ((, ), 3603), ((ARABIC DAMMA, ُ), 3025), ((ARABIC SUKUN, ْ), 1127), ((ARABIC FATHA+ARABIC SHADDA, َّ), 268), ((ARABIC KASRATAN, ٍ), 115), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 96), ((ARABIC FATHATAN, ً), 61), ((ARABIC DAMMATAN, ٌ), 54), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 49), ((ARABIC SHADDA, ّ), 11), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 6), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 5), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 4)]
# 11  [((ARABIC FATHA, َ), 3679), ((, ), 3162), ((ARABIC SUKUN, ْ), 2637), ((ARABIC KASRA, ِ), 2070), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1104), ((ARABIC DAMMA, ُ), 573), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 211), ((ARABIC KASRATAN, ٍ), 78), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 58), ((ARABIC FATHATAN, ً), 24), ((ARABIC DAMMATAN, ٌ), 21), ((ARABIC SHADDA, ّ), 16), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 11), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2), ((ARABIC KASRA+ARABIC SUKUN, ِْ), 1), ((ARABIC FATHA+ARABIC KASRA, َِ), 1)]
# 20                                                                                                                                                               [((ARABIC FATHA, َ), 1885), ((, ), 1742), ((ARABIC KASRA, ِ), 1300), ((ARABIC DAMMA, ُ), 963), ((ARABIC SUKUN, ْ), 343), ((ARABIC FATHA+ARABIC SHADDA, َّ), 14), ((ARABIC KASRATAN, ٍ), 11), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 7), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 7), ((ARABIC DAMMATAN, ٌ), 3), ((ARABIC FATHATAN, ً), 3), ((ARABIC KASRA+ARABIC KASRA, ِِ), 1)]
# 9                                                                                                                               [((, ), 6591), ((ARABIC FATHA, َ), 5537), ((ARABIC SUKUN, ْ), 1129), ((ARABIC KASRA, ِ), 492), ((ARABIC FATHA+ARABIC SHADDA, َّ), 197), ((ARABIC DAMMA, ُ), 124), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 82), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 51), ((ARABIC FATHATAN, ً), 14), ((ARABIC SHADDA, ّ), 13), ((ARABIC KASRATAN, ٍ), 3), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [((, ), 2295), ((ARABIC FATHA, َ), 2)]
# 6                                                             [((, ), 11678), ((ARABIC FATHA+ARABIC SHADDA, َّ), 2470), ((ARABIC FATHA, َ), 2393), ((ARABIC SUKUN, ْ), 1128), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 915), ((ARABIC DAMMA, ُ), 839), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 309), ((ARABIC KASRA, ِ), 159), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 127), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 117), ((ARABIC SHADDA, ّ), 95), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 70), ((ARABIC FATHATAN, ً), 11), ((ARABIC DAMMATAN, ٌ), 2)]
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 1)]
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 1)]
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 2)]
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [((ARABIC FATHA, َ), 2), ((, ), 2)]
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [((, ), 32)]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   []
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   []
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   []
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    []
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    []
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    []
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   []
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    []
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 1)]

# %% [markdown]
# # ClArTTS

# %%
# Test set
print(filenames[2])
info_df_2 = generate_information_report(filenames[2])
print("\nChecking the diacritics combinations in the dataset:\n")
print(
    Counter(
        [
            t[0][0]
            for l in info_df_2[info_df_2["Character"] != " "][
                "Following_diacritics"
            ].tolist()
            for t in l
            for _ in range(t[1])
        ]
    ).most_common()
)
print()

info_df_2
# Out:
# ../data/clartts_test_metadata.json
#
# Checking the diacritics combinations in the dataset:
#
# [('ARABIC FATHA', 2446), ('', 1448), ('ARABIC KASRA', 961), ('ARABIC SUKUN', 934), ('ARABIC DAMMA', 633), ('ARABIC FATHA+ARABIC SHADDA', 266), ('ARABIC KASRATAN', 61), ('ARABIC FATHATAN', 49), ('ARABIC KASRA+ARABIC SHADDA', 46), ('ARABIC DAMMATAN', 44), ('ARABIC DAMMA+ARABIC SHADDA', 39), ('ARABIC FATHATAN+ARABIC SHADDA', 7), ('ARABIC DAMMATAN+ARABIC SHADDA', 3), ('ARABIC KASRATAN+ARABIC SHADDA', 2), ('ARABIC SHADDA', 1)]
#    Character  Count  Code                                 Name Type  \
# 1              1489    32                                SPACE   Zs
# 39         ء     33  1569                  ARABIC LETTER HAMZA   Lo
# 43         آ      6  1570  ARABIC LETTER ALEF WITH MADDA ABOVE   Lo
# 19         أ    183  1571  ARABIC LETTER ALEF WITH HAMZA ABOVE   Lo
# 44         ؤ      5  1572   ARABIC LETTER WAW WITH HAMZA ABOVE   Lo
# 29         إ     70  1573  ARABIC LETTER ALEF WITH HAMZA BELOW   Lo
# 41         ئ     23  1574   ARABIC LETTER YEH WITH HAMZA ABOVE   Lo
# 4          ا    918  1575                   ARABIC LETTER ALEF   Lo
# 13         ب    288  1576                    ARABIC LETTER BEH   Lo
# 24         ة     87  1577            ARABIC LETTER TEH MARBUTA   Lo
# 17         ت    207  1578                    ARABIC LETTER TEH   Lo
# 36         ث     47  1579                   ARABIC LETTER THEH   Lo
# 25         ج     80  1580                   ARABIC LETTER JEEM   Lo
# 23         ح    121  1581                    ARABIC LETTER HAH   Lo
# 34         خ     52  1582                   ARABIC LETTER KHAH   Lo
# 21         د    176  1583                    ARABIC LETTER DAL   Lo
# 27         ذ     70  1584                   ARABIC LETTER THAL   Lo
# 15         ر    259  1585                    ARABIC LETTER REH   Lo
# 38         ز     33  1586                   ARABIC LETTER ZAIN   Lo
# 22         س    147  1587                   ARABIC LETTER SEEN   Lo
# 32         ش     54  1588                  ARABIC LETTER SHEEN   Lo
# 26         ص     70  1589                    ARABIC LETTER SAD   Lo
# 33         ض     53  1590                    ARABIC LETTER DAD   Lo
# 37         ط     45  1591                    ARABIC LETTER TAH   Lo
# 42         ظ     20  1592                    ARABIC LETTER ZAH   Lo
# 14         ع    285  1593                    ARABIC LETTER AIN   Lo
# 40         غ     30  1594                  ARABIC LETTER GHAIN   Lo
# 16         ف    246  1601                    ARABIC LETTER FEH   Lo
# 18         ق    191  1602                    ARABIC LETTER QAF   Lo
# 20         ك    177  1603                    ARABIC LETTER KAF   Lo
# 5          ل    820  1604                    ARABIC LETTER LAM   Lo
# 9          م    429  1605                   ARABIC LETTER MEEM   Lo
# 7          ن    446  1606                   ARABIC LETTER NOON   Lo
# 12         ه    341  1607                    ARABIC LETTER HEH   Lo
# 8          و    433  1608                    ARABIC LETTER WAW   Lo
# 28         ى     70  1609           ARABIC LETTER ALEF MAKSURA   Lo
# 10         ي    425  1610                    ARABIC LETTER YEH   Lo
# 31         ً     56  1611                      ARABIC FATHATAN   Mn
# 35         ٌ     47  1612                      ARABIC DAMMATAN   Mn
# 30         ٍ     63  1613                      ARABIC KASRATAN   Mn
# 0          َ   2714  1614                         ARABIC FATHA   Mn
# 6          ُ    672  1615                         ARABIC DAMMA   Mn
# 2          ِ   1007  1616                         ARABIC KASRA   Mn
# 11         ّ    364  1617                        ARABIC SHADDA   Mn
# 3          ْ    934  1618                         ARABIC SUKUN   Mn
#
#     is_diacritic  \
# 1          False
# 39         False
# 43         False
# 19         False
# 44         False
# 29         False
# 41         False
# 4          False
# 13         False
# 24         False
# 17         False
# 36         False
# 25         False
# 23         False
# 34         False
# 21         False
# 27         False
# 15         False
# 38         False
# 22         False
# 32         False
# 26         False
# 33         False
# 37         False
# 42         False
# 14         False
# 40         False
# 16         False
# 18         False
# 20         False
# 5          False
# 9          False
# 7          False
# 12         False
# 8          False
# 28         False
# 10         False
# 31          True
# 35          True
# 30          True
# 0           True
# 6           True
# 2           True
# 11          True
# 3           True
#
#                                                                                                                                                                                                                                                                                                                                                                                          Following_diacritics
# 1                                                                                                                                                                                                                                                                                                                                                                      [((, ), 1487), ((ARABIC FATHA, َ), 2)]
# 39                                                                                                                                                                                                                                                                            [((ARABIC KASRA, ِ), 15), ((ARABIC FATHA, َ), 8), ((ARABIC DAMMA, ُ), 7), ((ARABIC FATHATAN, ً), 2), ((ARABIC KASRATAN, ٍ), 1)]
# 43                                                                                                                                                                                                                                                                                                                                                                                                [((, ), 6)]
# 19                                                                                                                                                                                                                                                                                                                                [((ARABIC FATHA, َ), 163), ((ARABIC DAMMA, ُ), 13), ((ARABIC SUKUN, ْ), 7)]
# 44                                                                                                                                                                                                                                                                                                                                                           [((ARABIC FATHA, َ), 4), ((ARABIC DAMMA, ُ), 1)]
# 29                                                                                                                                                                                                                                                                                                                                                                      [((ARABIC KASRA, ِ), 42), ((, ), 28)]
# 41                                                                                                                                                                                                                                                    [((ARABIC KASRA, ِ), 17), ((ARABIC FATHA, َ), 2), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC FATHATAN, ً), 1), ((ARABIC DAMMA, ُ), 1), ((ARABIC SUKUN, ْ), 1)]
# 4                                                                                                                                                                                                                                                                                                                      [((, ), 914), ((ARABIC FATHA, َ), 2), ((ARABIC DAMMA, ُ), 1), ((ARABIC SHADDA, ّ), 1)]
# 13                                                                                                [((ARABIC KASRA, ِ), 103), ((ARABIC FATHA, َ), 93), ((ARABIC SUKUN, ْ), 40), ((ARABIC DAMMA, ُ), 30), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 3), ((ARABIC FATHATAN, ً), 2), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 24                                                                                                                                                                                                                                    [((ARABIC KASRA, ِ), 32), ((ARABIC KASRATAN, ٍ), 17), ((ARABIC DAMMA, ُ), 13), ((ARABIC FATHATAN, ً), 9), ((ARABIC DAMMATAN, ٌ), 8), ((ARABIC FATHA, َ), 7), ((, ), 1)]
# 17                                          [((ARABIC FATHA, َ), 107), ((ARABIC KASRA, ِ), 35), ((ARABIC DAMMA, ُ), 19), ((ARABIC FATHA+ARABIC SHADDA, َّ), 18), ((ARABIC SUKUN, ْ), 17), ((, ), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC FATHATAN, ً), 2), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC DAMMATAN, ٌ), 1), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1)]
# 36                                                                                                                                                                                                [((ARABIC DAMMA, ُ), 13), ((ARABIC FATHA+ARABIC SHADDA, َّ), 12), ((ARABIC FATHA, َ), 8), ((ARABIC KASRA, ِ), 7), ((ARABIC SUKUN, ْ), 4), ((ARABIC KASRATAN, ٍ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 25                                                                                                                                                                                                                                      [((ARABIC FATHA, َ), 48), ((ARABIC SUKUN, ْ), 11), ((ARABIC KASRA, ِ), 10), ((ARABIC DAMMA, ُ), 8), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1)]
# 23                                                                                                                                                                                                          [((ARABIC FATHA, َ), 62), ((ARABIC SUKUN, ْ), 21), ((ARABIC DAMMA, ُ), 18), ((ARABIC KASRA, ِ), 17), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC FATHATAN, ً), 1), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1)]
# 34                                                                                                                                                                                                                                                                              [((ARABIC FATHA, َ), 29), ((ARABIC SUKUN, ْ), 10), ((ARABIC KASRA, ِ), 8), ((ARABIC DAMMA, ُ), 4), ((ARABIC FATHATAN, ً), 1)]
# 21  [((ARABIC FATHA, َ), 53), ((ARABIC DAMMA, ُ), 36), ((ARABIC SUKUN, ْ), 32), ((ARABIC KASRA, ِ), 28), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC KASRATAN, ٍ), 6), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((, ), 1), ((ARABIC FATHATAN, ً), 1), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1), ((ARABIC DAMMATAN, ٌ), 1)]
# 27                                                                                                                                                                                                                                                                  [((ARABIC FATHA, َ), 44), ((ARABIC DAMMA, ُ), 10), ((ARABIC KASRA, ِ), 8), ((ARABIC SUKUN, ْ), 5), ((ARABIC FATHA+ARABIC SHADDA, َّ), 3)]
# 15                                                                                     [((ARABIC FATHA, َ), 84), ((ARABIC KASRA, ِ), 57), ((ARABIC DAMMA, ُ), 41), ((ARABIC SUKUN, ْ), 34), ((ARABIC FATHA+ARABIC SHADDA, َّ), 15), ((ARABIC DAMMATAN, ٌ), 8), ((ARABIC FATHATAN, ً), 7), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 5), ((ARABIC KASRATAN, ٍ), 3), ((, ), 3), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2)]
# 38                                                                                                                                                                                     [((ARABIC FATHA, َ), 10), ((ARABIC KASRA, ِ), 9), ((ARABIC DAMMA, ُ), 5), ((ARABIC SUKUN, ْ), 4), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC FATHA+ARABIC SHADDA, َّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 22                                                                                                                                            [((ARABIC FATHA, َ), 50), ((ARABIC SUKUN, ْ), 36), ((ARABIC KASRA, ِ), 25), ((ARABIC DAMMA, ُ), 19), ((ARABIC FATHA+ARABIC SHADDA, َّ), 7), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 3), ((, ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 32                                                                                                                                                                                                                            [((ARABIC FATHA, َ), 23), ((ARABIC SUKUN, ْ), 9), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((ARABIC KASRA, ِ), 6), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 5), ((ARABIC DAMMA, ُ), 3)]
# 26                                                                                                                                                                                                                           [((ARABIC FATHA, َ), 36), ((ARABIC KASRA, ِ), 15), ((ARABIC FATHA+ARABIC SHADDA, َّ), 7), ((ARABIC DAMMA, ُ), 6), ((ARABIC SUKUN, ْ), 4), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2)]
# 33                                                                                                                                                                                                                                                                             [((ARABIC FATHA, َ), 24), ((ARABIC DAMMA, ُ), 13), ((ARABIC KASRA, ِ), 11), ((ARABIC SUKUN, ْ), 4), ((ARABIC FATHATAN, ً), 1)]
# 37                                                                                                                                                          [((ARABIC FATHA, َ), 20), ((ARABIC DAMMA, ُ), 7), ((ARABIC FATHA+ARABIC SHADDA, َّ), 6), ((ARABIC KASRA, ِ), 5), ((ARABIC SUKUN, ْ), 3), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC FATHATAN, ً), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 42                                                                                                                                                                                                                              [((ARABIC FATHA, َ), 8), ((ARABIC SUKUN, ْ), 3), ((ARABIC DAMMA, ُ), 3), ((ARABIC KASRA, ِ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2), ((, ), 1), ((ARABIC FATHATAN, ً), 1)]
# 14                                                                                                                                                                                                                     [((ARABIC FATHA, َ), 174), ((ARABIC SUKUN, ْ), 46), ((ARABIC KASRA, ِ), 35), ((ARABIC DAMMA, ُ), 23), ((ARABIC KASRATAN, ٍ), 3), ((ARABIC FATHATAN, ً), 2), ((ARABIC DAMMATAN, ٌ), 2)]
# 40                                                                                                                                                                                                                                                                                                                                  [((ARABIC FATHA, َ), 14), ((ARABIC SUKUN, ْ), 9), ((ARABIC KASRA, ِ), 7)]
# 16                                                                                                                [((ARABIC FATHA, َ), 138), ((ARABIC KASRA, ِ), 59), ((ARABIC SUKUN, ْ), 19), ((ARABIC DAMMA, ُ), 16), ((ARABIC DAMMATAN, ٌ), 3), ((ARABIC FATHA+ARABIC SHADDA, َّ), 3), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2), ((ARABIC KASRATAN, ٍ), 2), ((, ), 2), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2)]
# 18                                                                                                                        [((ARABIC FATHA, َ), 120), ((ARABIC SUKUN, ْ), 21), ((ARABIC KASRA, ِ), 20), ((ARABIC DAMMA, ُ), 18), ((ARABIC KASRATAN, ٍ), 4), ((ARABIC FATHATAN, ً), 4), ((ARABIC FATHA+ARABIC SHADDA, َّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 20                                                                                                                                                                                  [((ARABIC FATHA, َ), 75), ((ARABIC DAMMA, ُ), 43), ((, ), 27), ((ARABIC SUKUN, ْ), 17), ((ARABIC KASRA, ِ), 11), ((ARABIC DAMMATAN, ٌ), 2), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 5                                       [((ARABIC FATHA, َ), 244), ((ARABIC SUKUN, ْ), 203), ((, ), 127), ((ARABIC KASRA, ِ), 104), ((ARABIC FATHA+ARABIC SHADDA, َّ), 73), ((ARABIC DAMMA, ُ), 43), ((ARABIC DAMMATAN, ٌ), 8), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 7), ((ARABIC FATHATAN, ً), 4), ((ARABIC KASRATAN, ٍ), 4), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1)]
# 9                                           [((ARABIC FATHA, َ), 190), ((ARABIC KASRA, ِ), 97), ((ARABIC DAMMA, ُ), 60), ((ARABIC SUKUN, ْ), 49), ((ARABIC FATHA+ARABIC SHADDA, َّ), 14), ((ARABIC FATHATAN, ً), 6), ((ARABIC KASRATAN, ٍ), 4), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 3), ((, ), 2), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 1), ((ARABIC DAMMATAN, ٌ), 1)]
# 7                                                                                     [((ARABIC SUKUN, ْ), 206), ((ARABIC FATHA, َ), 98), ((ARABIC FATHA+ARABIC SHADDA, َّ), 58), ((ARABIC KASRA, ِ), 49), ((ARABIC DAMMA, ُ), 18), ((ARABIC DAMMATAN, ٌ), 5), ((, ), 3), ((ARABIC FATHATAN, ً), 3), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC KASRATAN, ٍ), 2)]
# 12                                                                                                                                                                                             [((ARABIC DAMMA, ُ), 121), ((ARABIC KASRA, ِ), 112), ((ARABIC FATHA, َ), 84), ((ARABIC SUKUN, ْ), 16), ((, ), 5), ((ARABIC FATHATAN, ً), 1), ((ARABIC FATHA+ARABIC SHADDA, َّ), 1), ((ARABIC DAMMATAN, ٌ), 1)]
# 8                                                                                                                                                                       [((ARABIC FATHA, َ), 289), ((, ), 89), ((ARABIC SUKUN, ْ), 29), ((ARABIC KASRA, ِ), 11), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 2), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 2), ((ARABIC DAMMA, ُ), 2)]
# 28                                                                                                                                                                                                                                                                                                                                                                                               [((, ), 70)]
# 10                                                                                [((, ), 165), ((ARABIC FATHA, َ), 135), ((ARABIC SUKUN, ْ), 74), ((ARABIC DAMMA, ُ), 18), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 12), ((ARABIC FATHA+ARABIC SHADDA, َّ), 9), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 5), ((ARABIC KASRA, ِ), 4), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 31                                                                                                                                                                                                                                                                                                                                                                                                         []
# 35                                                                                                                                                                                                                                                                                                                                                                                                         []
# 30                                                                                                                                                                                                                                                                                                                                                                                                         []
# 0                                                                                                                                                                                                                                                                                                                                                                                                          []
# 6                                                                                                                                                                                                                                                                                                                                                                                                          []
# 2                                                                                                                                                                                                                                                                                                                                                                                                          []
# 11                                                                                                                                                                                                                                                                                                                                                                                                         []
# 3                                                                                                                                                                                                                                                                                                                                                                                                          []

# %%
# Train set
print(filenames[3])
info_df_3 = generate_information_report(filenames[3])
print("\nChecking the diacritics combinations in the dataset:\n")
print(
    Counter(
        [
            t[0][0]
            for l in info_df_3[info_df_3["Character"] != " "][
                "Following_diacritics"
            ].tolist()
            for t in l
            for _ in range(t[1])
        ]
    ).most_common()
)
print()

info_df_3
# Out:
# ../data/clartts_train_metadata.json
#
# Checking the diacritics combinations in the dataset:
#
# [('ARABIC FATHA', 108430), ('', 69968), ('ARABIC KASRA', 43507), ('ARABIC SUKUN', 43105), ('ARABIC DAMMA', 28448), ('ARABIC FATHA+ARABIC SHADDA', 11981), ('ARABIC FATHATAN', 2529), ('ARABIC KASRA+ARABIC SHADDA', 2335), ('ARABIC KASRATAN', 2225), ('ARABIC DAMMA+ARABIC SHADDA', 2145), ('ARABIC DAMMATAN', 2121), ('ARABIC FATHATAN+ARABIC SHADDA', 177), ('ARABIC DAMMATAN+ARABIC SHADDA', 160), ('ARABIC KASRATAN+ARABIC SHADDA', 136), ('ARABIC SHADDA', 39), ('ARABIC KASRA+ARABIC KASRA', 1), ('ARABIC SHADDA+ARABIC SUKUN', 1), ('ARABIC DAMMA+ARABIC KASRA', 1), ('ARABIC FATHA+ARABIC DAMMA', 1)]
#    Character   Count  Code                                 Name Type  \
# 1              66780    32                                SPACE   Zs
# 37         ء    1874  1569                  ARABIC LETTER HAMZA   Lo
# 43         آ     361  1570  ARABIC LETTER ALEF WITH MADDA ABOVE   Lo
# 19         أ    8382  1571  ARABIC LETTER ALEF WITH HAMZA ABOVE   Lo
# 44         ؤ     337  1572   ARABIC LETTER WAW WITH HAMZA ABOVE   Lo
# 25         إ    3882  1573  ARABIC LETTER ALEF WITH HAMZA BELOW   Lo
# 41         ئ     930  1574   ARABIC LETTER YEH WITH HAMZA ABOVE   Lo
# 3          ا   44070  1575                   ARABIC LETTER ALEF   Lo
# 15         ب   12396  1576                    ARABIC LETTER BEH   Lo
# 24         ة    4266  1577            ARABIC LETTER TEH MARBUTA   Lo
# 17         ت    9673  1578                    ARABIC LETTER TEH   Lo
# 39         ث    1794  1579                   ARABIC LETTER THEH   Lo
# 27         ج    3443  1580                   ARABIC LETTER JEEM   Lo
# 23         ح    5506  1581                    ARABIC LETTER HAH   Lo
# 32         خ    2497  1582                   ARABIC LETTER KHAH   Lo
# 20         د    7707  1583                    ARABIC LETTER DAL   Lo
# 29         ذ    3109  1584                   ARABIC LETTER THAL   Lo
# 14         ر   12559  1585                    ARABIC LETTER REH   Lo
# 38         ز    1809  1586                   ARABIC LETTER ZAIN   Lo
# 22         س    6924  1587                   ARABIC LETTER SEEN   Lo
# 34         ش    2338  1588                  ARABIC LETTER SHEEN   Lo
# 28         ص    3172  1589                    ARABIC LETTER SAD   Lo
# 31         ض    2547  1590                    ARABIC LETTER DAD   Lo
# 36         ط    2005  1591                    ARABIC LETTER TAH   Lo
# 42         ظ     764  1592                    ARABIC LETTER ZAH   Lo
# 13         ع   12789  1593                    ARABIC LETTER AIN   Lo
# 40         غ    1678  1594                  ARABIC LETTER GHAIN   Lo
# 16         ف    9973  1601                    ARABIC LETTER FEH   Lo
# 18         ق    8532  1602                    ARABIC LETTER QAF   Lo
# 21         ك    7486  1603                    ARABIC LETTER KAF   Lo
# 5          ل   40358  1604                    ARABIC LETTER LAM   Lo
# 7          م   20223  1605                   ARABIC LETTER MEEM   Lo
# 8          ن   19068  1606                   ARABIC LETTER NOON   Lo
# 12         ه   14310  1607                    ARABIC LETTER HEH   Lo
# 9          و   18910  1608                    ARABIC LETTER WAW   Lo
# 26         ى    3445  1609           ARABIC LETTER ALEF MAKSURA   Lo
# 10         ي   18193  1610                    ARABIC LETTER YEH   Lo
# 30         ً    2706  1611                      ARABIC FATHATAN   Mn
# 35         ٌ    2281  1612                      ARABIC DAMMATAN   Mn
# 33         ٍ    2363  1613                      ARABIC KASRATAN   Mn
# 0          َ  120444  1614                         ARABIC FATHA   Mn
# 6          ُ   30601  1615                         ARABIC DAMMA   Mn
# 2          ِ   45853  1616                         ARABIC KASRA   Mn
# 11         ّ   16975  1617                        ARABIC SHADDA   Mn
# 4          ْ   43111  1618                         ARABIC SUKUN   Mn
#
#     is_diacritic  \
# 1          False
# 37         False
# 43         False
# 19         False
# 44         False
# 25         False
# 41         False
# 3          False
# 15         False
# 24         False
# 17         False
# 39         False
# 27         False
# 23         False
# 32         False
# 20         False
# 29         False
# 14         False
# 38         False
# 22         False
# 34         False
# 28         False
# 31         False
# 36         False
# 42         False
# 13         False
# 40         False
# 16         False
# 18         False
# 21         False
# 5          False
# 7          False
# 8          False
# 12         False
# 9          False
# 26         False
# 10         False
# 30          True
# 35          True
# 33          True
# 0           True
# 6           True
# 2           True
# 11          True
# 4           True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Following_diacritics
# 1                                                                                                                                                                                                                                                                                                                                                                             [((, ), 66736), ((ARABIC FATHA, َ), 27), ((ARABIC KASRA, ِ), 7), ((ARABIC DAMMA, ُ), 4), ((ARABIC SUKUN, ْ), 4), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC SHADDA, ّ), 1)]
# 37                                                                                                                                                                                                                                                                                                   [((ARABIC KASRA, ِ), 1005), ((ARABIC FATHA, َ), 333), ((ARABIC DAMMA, ُ), 277), ((ARABIC KASRATAN, ٍ), 88), ((ARABIC DAMMATAN, ٌ), 72), ((ARABIC FATHATAN, ً), 61), ((, ), 33), ((ARABIC SUKUN, ْ), 4), ((ARABIC KASRA+ARABIC KASRA, ِِ), 1)]
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [((, ), 361)]
# 19                                                                                                                                                                                                                                                                                                                                           [((ARABIC FATHA, َ), 7419), ((ARABIC DAMMA, ُ), 503), ((ARABIC SUKUN, ْ), 411), ((ARABIC FATHATAN, ً), 20), ((, ), 19), ((ARABIC KASRA, ِ), 6), ((ARABIC DAMMATAN, ٌ), 3), ((ARABIC KASRATAN, ٍ), 1)]
# 44                                                                                                                                                                                                                                                                                                                                                                                                                [((ARABIC SUKUN, ْ), 132), ((ARABIC FATHA, َ), 126), ((ARABIC DAMMA, ُ), 72), ((ARABIC DAMMATAN, ٌ), 6), ((ARABIC KASRA, ِ), 1)]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [((, ), 2217), ((ARABIC KASRA, ِ), 1663), ((ARABIC FATHA, َ), 2)]
# 41                                                                                                                                                                                                                                                                                                                                             [((ARABIC KASRA, ِ), 670), ((ARABIC FATHA, َ), 85), ((ARABIC DAMMA, ُ), 65), ((ARABIC SUKUN, ْ), 43), ((ARABIC FATHATAN, ً), 42), ((ARABIC KASRATAN, ٍ), 19), ((, ), 4), ((ARABIC DAMMATAN, ٌ), 2)]
# 3                                                                                                                                                                                                                                                                                                                                                                                                    [((, ), 43907), ((ARABIC FATHA, َ), 99), ((ARABIC DAMMA, ُ), 44), ((ARABIC KASRA, ِ), 10), ((ARABIC FATHATAN, ً), 8), ((ARABIC SUKUN, ْ), 2)]
# 15                                               [((ARABIC KASRA, ِ), 4533), ((ARABIC FATHA, َ), 3771), ((ARABIC SUKUN, ْ), 1781), ((ARABIC DAMMA, ُ), 1215), ((ARABIC FATHA+ARABIC SHADDA, َّ), 257), ((ARABIC KASRATAN, ٍ), 198), ((ARABIC FATHATAN, ً), 177), ((ARABIC DAMMATAN, ٌ), 162), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 114), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 88), ((, ), 74), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 12), ((ARABIC SHADDA, ّ), 5), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 5), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 4)]
# 24                                                                                                                                                                                                                                                                                                                                      [((ARABIC KASRA, ِ), 1484), ((ARABIC DAMMA, ُ), 884), ((ARABIC DAMMATAN, ٌ), 540), ((ARABIC FATHA, َ), 506), ((ARABIC FATHATAN, ً), 396), ((ARABIC KASRATAN, ٍ), 360), ((, ), 95), ((ARABIC SUKUN, ْ), 1)]
# 17                                                                                                                                                                  [((ARABIC FATHA, َ), 5018), ((ARABIC KASRA, ِ), 1553), ((ARABIC DAMMA, ُ), 948), ((ARABIC SUKUN, ْ), 906), ((ARABIC FATHA+ARABIC SHADDA, َّ), 724), ((, ), 366), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 51), ((ARABIC KASRATAN, ٍ), 40), ((ARABIC DAMMATAN, ٌ), 24), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 24), ((ARABIC FATHATAN, ً), 17), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 2)]
# 39                                                                                                                             [((ARABIC FATHA, َ), 603), ((ARABIC DAMMA, ُ), 426), ((ARABIC FATHA+ARABIC SHADDA, َّ), 246), ((ARABIC SUKUN, ْ), 209), ((ARABIC KASRA, ِ), 204), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 33), ((ARABIC FATHATAN, ً), 22), ((ARABIC KASRATAN, ٍ), 21), ((ARABIC DAMMATAN, ٌ), 16), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((, ), 4), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1)]
# 27                                                                                                       [((ARABIC FATHA, َ), 1708), ((ARABIC SUKUN, ْ), 605), ((ARABIC KASRA, ِ), 532), ((ARABIC DAMMA, ُ), 463), ((ARABIC FATHA+ARABIC SHADDA, َّ), 61), ((, ), 18), ((ARABIC FATHATAN, ً), 15), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 14), ((ARABIC DAMMATAN, ٌ), 13), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 6), ((ARABIC KASRATAN, ٍ), 5), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC SHADDA+ARABIC SUKUN, ّْ), 1), ((ARABIC SHADDA, ّ), 1)]
# 23                                                                                 [((ARABIC FATHA, َ), 2530), ((ARABIC KASRA, ِ), 951), ((ARABIC SUKUN, ْ), 949), ((ARABIC DAMMA, ُ), 821), ((ARABIC FATHA+ARABIC SHADDA, َّ), 56), ((ARABIC FATHATAN, ً), 53), ((ARABIC KASRATAN, ٍ), 48), ((ARABIC DAMMATAN, ٌ), 42), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 21), ((, ), 19), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 10), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 4), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 32                                                                                                                                                                                                                 [((ARABIC FATHA, َ), 1261), ((ARABIC SUKUN, ْ), 644), ((ARABIC KASRA, ِ), 300), ((ARABIC DAMMA, ُ), 244), ((ARABIC FATHATAN, ً), 13), ((ARABIC KASRATAN, ٍ), 10), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((, ), 6), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 6), ((ARABIC DAMMATAN, ٌ), 4), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1)]
# 20                                             [((ARABIC FATHA, َ), 2331), ((ARABIC SUKUN, ْ), 1487), ((ARABIC KASRA, ِ), 1234), ((ARABIC DAMMA, ُ), 1027), ((ARABIC FATHA+ARABIC SHADDA, َّ), 461), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 320), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 236), ((ARABIC KASRATAN, ٍ), 217), ((ARABIC FATHATAN, ً), 180), ((ARABIC DAMMATAN, ٌ), 138), ((, ), 37), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 17), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 12), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 9), ((ARABIC SHADDA, ّ), 1)]
# 29                                                                                                                                                                                                                  [((ARABIC FATHA, َ), 1916), ((ARABIC KASRA, ِ), 543), ((ARABIC SUKUN, ْ), 298), ((ARABIC DAMMA, ُ), 169), ((ARABIC FATHA+ARABIC SHADDA, َّ), 93), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 29), ((ARABIC FATHATAN, ً), 24), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 19), ((ARABIC KASRATAN, ٍ), 8), ((ARABIC DAMMATAN, ٌ), 6), ((, ), 4)]
# 14                                            [((ARABIC FATHA, َ), 4645), ((ARABIC KASRA, ِ), 2495), ((ARABIC DAMMA, ُ), 2036), ((ARABIC SUKUN, ْ), 1349), ((ARABIC FATHA+ARABIC SHADDA, َّ), 581), ((ARABIC FATHATAN, ً), 317), ((ARABIC DAMMATAN, ٌ), 292), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 260), ((ARABIC KASRATAN, ٍ), 235), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 174), ((, ), 96), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 27), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 27), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 19), ((ARABIC SHADDA, ّ), 6)]
# 38                                                                                 [((ARABIC FATHA, َ), 656), ((ARABIC KASRA, ِ), 404), ((ARABIC SUKUN, ْ), 241), ((ARABIC FATHA+ARABIC SHADDA, َّ), 149), ((ARABIC DAMMA, ُ), 148), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 67), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 66), ((ARABIC FATHATAN, ً), 21), ((ARABIC KASRATAN, ٍ), 20), ((ARABIC DAMMATAN, ٌ), 19), ((, ), 12), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1)]
# 22                                                                                              [((ARABIC FATHA, َ), 2575), ((ARABIC SUKUN, ْ), 1800), ((ARABIC KASRA, ِ), 1033), ((ARABIC DAMMA, ُ), 762), ((ARABIC FATHA+ARABIC SHADDA, َّ), 374), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 130), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 74), ((ARABIC KASRATAN, ٍ), 72), ((ARABIC FATHATAN, ً), 40), ((, ), 37), ((ARABIC DAMMATAN, ٌ), 23), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 2), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC SHADDA, ّ), 1)]
# 34                                                                                                                                                                                                                 [((ARABIC FATHA, َ), 940), ((ARABIC FATHA+ARABIC SHADDA, َّ), 371), ((ARABIC SUKUN, ْ), 364), ((ARABIC KASRA, ِ), 232), ((ARABIC DAMMA, ُ), 215), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 158), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 27), ((ARABIC KASRATAN, ٍ), 18), ((ARABIC FATHATAN, ً), 8), ((ARABIC DAMMATAN, ٌ), 4), ((, ), 1)]
# 28                                                        [((ARABIC FATHA, َ), 1395), ((ARABIC KASRA, ِ), 550), ((ARABIC SUKUN, ْ), 493), ((ARABIC FATHA+ARABIC SHADDA, َّ), 315), ((ARABIC DAMMA, ُ), 226), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 100), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 49), ((ARABIC KASRATAN, ٍ), 11), ((ARABIC FATHATAN, ً), 11), ((ARABIC DAMMATAN, ٌ), 9), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 6), ((, ), 3), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 2), ((ARABIC SHADDA, ّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 31                                                                                                                                                                       [((ARABIC FATHA, َ), 794), ((ARABIC DAMMA, ُ), 678), ((ARABIC KASRA, ِ), 635), ((ARABIC SUKUN, ْ), 238), ((ARABIC FATHA+ARABIC SHADDA, َّ), 64), ((ARABIC FATHATAN, ً), 42), ((ARABIC KASRATAN, ٍ), 35), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 31), ((ARABIC DAMMATAN, ٌ), 14), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 11), ((, ), 4), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 1)]
# 36                                                                                                                                                                                                                [((ARABIC FATHA, َ), 974), ((ARABIC KASRA, ِ), 339), ((ARABIC SUKUN, ْ), 229), ((ARABIC FATHA+ARABIC SHADDA, َّ), 206), ((ARABIC DAMMA, ُ), 154), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 33), ((ARABIC KASRATAN, ٍ), 18), ((ARABIC DAMMATAN, ٌ), 17), ((ARABIC FATHATAN, ً), 14), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 14), ((, ), 7)]
# 42                                                                                                 [((ARABIC FATHA, َ), 302), ((ARABIC DAMMA, ُ), 118), ((ARABIC SUKUN, ْ), 111), ((ARABIC KASRA, ِ), 86), ((ARABIC FATHA+ARABIC SHADDA, َّ), 76), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 21), ((ARABIC FATHATAN, ً), 15), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 11), ((ARABIC KASRATAN, ٍ), 8), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 6), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 5), ((ARABIC DAMMATAN, ٌ), 4), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 13                                                                                                                                                                                                              [((ARABIC FATHA, َ), 7258), ((ARABIC SUKUN, ْ), 2402), ((ARABIC KASRA, ِ), 1671), ((ARABIC DAMMA, ُ), 1111), ((ARABIC FATHATAN, ً), 127), ((ARABIC DAMMATAN, ٌ), 92), ((ARABIC KASRATAN, ٍ), 72), ((, ), 41), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 7), ((ARABIC FATHA+ARABIC SHADDA, َّ), 5), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 3)]
# 40                                                                                                                                                                                                                                                               [((ARABIC FATHA, َ), 952), ((ARABIC SUKUN, ْ), 360), ((ARABIC KASRA, ِ), 258), ((ARABIC DAMMA, ُ), 88), ((ARABIC FATHA+ARABIC SHADDA, َّ), 8), ((ARABIC FATHATAN, ً), 4), ((ARABIC DAMMATAN, ٌ), 4), ((, ), 2), ((ARABIC KASRATAN, ٍ), 1), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 1)]
# 16                                                                              [((ARABIC FATHA, َ), 5060), ((ARABIC KASRA, ِ), 2803), ((ARABIC SUKUN, ْ), 1078), ((ARABIC DAMMA, ُ), 645), ((ARABIC FATHA+ARABIC SHADDA, َّ), 114), ((ARABIC FATHATAN, ً), 86), ((ARABIC KASRATAN, ٍ), 57), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 38), ((ARABIC DAMMATAN, ٌ), 36), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 29), ((, ), 23), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 18                                                                           [((ARABIC FATHA, َ), 5130), ((ARABIC KASRA, ِ), 1153), ((ARABIC SUKUN, ْ), 1016), ((ARABIC DAMMA, ُ), 751), ((ARABIC FATHA+ARABIC SHADDA, َّ), 103), ((ARABIC FATHATAN, ً), 83), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 80), ((ARABIC KASRATAN, ٍ), 56), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 55), ((ARABIC DAMMATAN, ٌ), 44), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 20), ((, ), 20), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 11), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 10)]
# 21                                                                              [((ARABIC FATHA, َ), 3472), ((ARABIC DAMMA, ُ), 1469), ((, ), 1028), ((ARABIC SUKUN, ْ), 793), ((ARABIC KASRA, ِ), 561), ((ARABIC FATHA+ARABIC SHADDA, َّ), 46), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 32), ((ARABIC KASRATAN, ٍ), 23), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 22), ((ARABIC FATHATAN, ً), 20), ((ARABIC DAMMATAN, ٌ), 16), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 1), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 1)]
# 5   [((ARABIC FATHA, َ), 12077), ((ARABIC SUKUN, ْ), 9821), ((, ), 6482), ((ARABIC KASRA, ِ), 5331), ((ARABIC FATHA+ARABIC SHADDA, َّ), 3369), ((ARABIC DAMMA, ُ), 1865), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 316), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 291), ((ARABIC FATHATAN, ً), 269), ((ARABIC KASRATAN, ٍ), 254), ((ARABIC DAMMATAN, ٌ), 232), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 21), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 15), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 11), ((ARABIC SHADDA, ّ), 3), ((ARABIC DAMMA+ARABIC KASRA, ُِ), 1)]
# 7                                               [((ARABIC FATHA, َ), 8946), ((ARABIC KASRA, ِ), 4032), ((ARABIC DAMMA, ُ), 3024), ((ARABIC SUKUN, ْ), 2537), ((ARABIC FATHA+ARABIC SHADDA, َّ), 818), ((ARABIC FATHATAN, ً), 229), ((ARABIC KASRATAN, ٍ), 206), ((ARABIC DAMMATAN, ٌ), 147), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 94), ((, ), 73), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 69), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 15), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 14), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 13), ((ARABIC SHADDA, ّ), 6)]
# 8                                                [((ARABIC SUKUN, ْ), 7479), ((ARABIC FATHA, َ), 4561), ((ARABIC FATHA+ARABIC SHADDA, َّ), 2833), ((ARABIC KASRA, ِ), 1969), ((ARABIC DAMMA, ُ), 1397), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 262), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 141), ((ARABIC FATHATAN, ً), 124), ((ARABIC DAMMATAN, ٌ), 111), ((, ), 98), ((ARABIC KASRATAN, ٍ), 78), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 6), ((ARABIC SHADDA, ّ), 4), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 3), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 2)]
# 12                                                                                                                                               [((ARABIC DAMMA, ُ), 5381), ((ARABIC KASRA, ِ), 4668), ((ARABIC FATHA, َ), 3236), ((ARABIC SUKUN, ْ), 746), ((, ), 145), ((ARABIC FATHA+ARABIC SHADDA, َّ), 47), ((ARABIC KASRATAN, ٍ), 36), ((ARABIC FATHATAN, ً), 23), ((ARABIC DAMMATAN, ٌ), 17), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 5), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 3), ((ARABIC SHADDA, ّ), 2), ((ARABIC FATHA+ARABIC DAMMA, َُ), 1)]
# 9                                                                             [((ARABIC FATHA, َ), 12361), ((, ), 4092), ((ARABIC SUKUN, ْ), 1505), ((ARABIC KASRA, ِ), 484), ((ARABIC FATHA+ARABIC SHADDA, َّ), 172), ((ARABIC DAMMA, ُ), 158), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 61), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 31), ((ARABIC FATHATAN, ً), 15), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 10), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 10), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 4), ((ARABIC KASRATAN, ٍ), 4), ((ARABIC DAMMATAN, ٌ), 3)]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [((, ), 3443), ((ARABIC FATHA, َ), 2)]
# 10                                                [((, ), 7197), ((ARABIC FATHA, َ), 5386), ((ARABIC SUKUN, ْ), 3071), ((ARABIC DAMMA, ُ), 1064), ((ARABIC FATHA+ARABIC SHADDA, َّ), 424), ((ARABIC KASRA+ARABIC SHADDA, ِّ), 421), ((ARABIC DAMMA+ARABIC SHADDA, ُّ), 316), ((ARABIC KASRA, ِ), 114), ((ARABIC FATHATAN, ً), 53), ((ARABIC FATHATAN+ARABIC SHADDA, ًّ), 44), ((ARABIC KASRATAN+ARABIC SHADDA, ٍّ), 41), ((ARABIC DAMMATAN+ARABIC SHADDA, ٌّ), 38), ((ARABIC SHADDA, ّ), 9), ((ARABIC DAMMATAN, ٌ), 9), ((ARABIC KASRATAN, ٍ), 6)]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               []
